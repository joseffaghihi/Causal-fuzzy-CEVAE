# %% [markdown]
# >[Prepration of EEG smart reader](#scrollTo=04D_jHiClylt)
#
# >[Body of EEG smart reader](#scrollTo=AIUDAbfhqmIa)
#
# >[FFT](#scrollTo=XRIGL9-bsYCb)
#
# >[Conditional_Variational Autoencoder (Part A)_Good_Quad_train dual_test](#scrollTo=IxVOfTXWgpJd)
#
# >[CEVAE(part B)_Good_Quad_train dual_test](#scrollTo=mDvdIFzs2zXZ)
#
# >[Conditional_Variational Autoencoder (Part A)_Bad_Quad_train dual_test](#scrollTo=pimbqWLD3X1_)
#
# >[CEVAE(part B)_Bad_Quad_train dual_test](#scrollTo=zFfBogGB3oEX)

# %% [markdown]
# # Prepration of EEG smart reader

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from tqdm import tqdm
import glob
from dateutil.parser import parse
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#id
# %cd gdrive/MyDrive/Sajjad_cloned_ready
# !unzip 'Sajjad cloned_id.zip'
# Out:
# /content/gdrive/MyDrive/Sajjad_cloned_ready
# Archive:  Sajjad cloned_id.zip
# replace 1 (12)/296707.xlsx? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: 1 (12)/296707.xlsx
#   inflating: 1 (12)/Fichiers text/296707, 01-03-2021,Uni, Ti-1, -.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 01-03-2021,Uni, Ti-2, $.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 01-09-2021,BiT,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 02-06-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 05-03-2021,Uni, Tt, $.txt
#   inflating: 1 (12)/Fichiers text/296707, 08-03-2021,Uni, Tt, $.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 10-03-2021,Uni, Tt-1.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 10-03-2021,Uni, Tt-2.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 12-03-2021,BiF, Ti-1, -.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 12-03-2021,BiF, Ti-2, $.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 15-03-2021,BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 21-04-2021,BiF,$-.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 24-03-2021,BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 28-05-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 30-08-2021,BiT,Ti.dat.txt
#   inflating: 1 (12)/Fichiers text/296707, 31-05-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,07-04-2021, BiF,$-artefact EEG2.txt
#   inflating: 1 (12)/Fichiers text/296707,07-06-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,08-09-2021, BiF,Ti,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,09--04-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,09-06-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,12-04-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,14-04-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,14-06-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,16-06-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,17-03-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,17-05-2021, BiF,Ti,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,19-04-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,19-05-2021, BiF,Tt.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,22-03-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,26-05-2021, BiF.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,29-03-2021, BiF,$.dat.txt
#   inflating: 1 (12)/Fichiers text/296707,31-03-2021, BiF,$.dat.txt
#   inflating: 1 (13)/325733.xlsx
#   inflating: 1 (13)/Fichiers text/325733, 17-07-2020,Uni,$.dat.txt
#   inflating: 1 (13)/Fichiers text/325733, 20-07-2020, Uni, $.dat.txt
#   inflating: 1 (13)/Fichiers text/325733,15-07-2020, Ti, Uni,$.dat.txt
#   inflating: 1 (14)/334217.xlsx
#   inflating: 1 (14)/Fichiers text/334217, 02-08-2021, Uni, $.dat.txt
#   inflating: 1 (14)/Fichiers text/334217, 30-07-2021, Uni, Ti.dat.txt
#   inflating: 1 (15)/348655.xlsx
#   inflating: 1 (15)/Fichiers text/348655, 23-10-2019,Uni,$.txt
#   inflating: 1 (15)/Fichiers text/348655,13-01-2020,Uni,$.txt
#   inflating: 1 (15)/Fichiers text/348655,24-02-2020,Uni,$.txt
#   inflating: 1 (16)/353456.xlsx
#   inflating: 1 (16)/Fichiers text/353456, 11-03-2020,BiT,$.txt
#   inflating: 1 (16)/Fichiers text/353456, 13-03-2020,BiT,$.txt
#   inflating: 1 (16)/Fichiers text/353456, 18-03-2020,BiT.txt
#   inflating: 1 (16)/Fichiers text/353456, 20-03-2020,BiT,$.dat.txt
#   inflating: 1 (16)/Fichiers text/353456, 24-01-2020,BiT,$.txt
#   inflating: 1 (16)/Fichiers text/353456, 25-03-2020, BiT,$.dat.txt
#   inflating: 1 (16)/Fichiers text/353456, 27-03-2020,BiT$.dat.txt
#   inflating: 1 (17)/354886.xlsx
#   inflating: 1 (17)/Fichiers text/354886, 29-10-2019, BiF.txt
#   inflating: 1 (17)/Fichiers text/354886,06-01,2020,BiF,$.txt
#   inflating: 1 (17)/Fichiers text/354886,11-08-2021,BiF,$.dat.txt
#   inflating: 1 (17)/Fichiers text/354886,16-08-2021,BiF,$.dat.txt
#   inflating: 1 (17)/Fichiers text/354886,30-08-2021,BiF,$.dat.txt
#   inflating: 1 (18)/369690.xlsx
#   inflating: 1 (18)/Fichiers text/369690, 02-09-2020,BiF,$.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 04-09-2020,BiF,$.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 09-09-2020,BiF,Artefact sur EEG-2,$.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 17-08-2020,BiF,Ti-1,-.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 17-08-2020,BiF,Ti-2,-.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 17-08-2020,BiF,Ti-3,-.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 19-08-2020,BiF,Ti-1,-.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 21-08-2020,BiF, Ti.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 24-08-2020,BiF,$.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 26-08-2020,BiF,1.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 26-08-2020,BiF,2.dat.txt
#   inflating: 1 (18)/Fichiers text/369690, 31-08-2020,BiF,Ti.dat.txt
#   inflating: 1 (19)/377765.xlsx
#   inflating: 1 (19)/Fichiers text/377765,20-01-2020,Uni.txt
#   inflating: 1 (19)/Fichiers text/377765,22-01-2020,Uni,1,-.txt
#   inflating: 1 (19)/Fichiers text/377765,22-01-2020,Uni,2,$.txt
#   inflating: 1 (20)/388304.xlsx
#   inflating: 1 (20)/Fichiers text/388304,14-09-2020,Unil,Ti,$.dat.txt
#   inflating: 1 (21)/465293.xlsx
#   inflating: 1 (21)/Fichiers text/465293, 29-10-2019,BiF,$.txt
#   inflating: 1 (21)/Fichiers text/465293,23-12-2019,BiF,$.txt
#   inflating: 1 (21)/Fichiers text/465293,25-11-2019, BiF,$.txt
#   inflating: 1 (22)/465293.xlsx
#   inflating: 1 (22)/Fichiers text/465293, 19-02-2020,BiF,$.txt
#   inflating: 1 (22)/Fichiers text/465293,20-01-2020,BiF,$.txt
#   inflating: 1 (23)/494811.xlsx
#   inflating: 1 (23)/Fichiers text/494811,12-11-2019,BiT,$.txt
#   inflating: 1 (23)/Fichiers text/494811,23-12-2019,BiT,$.txt
#   inflating: 1 (24)/514538.xlsx
#   inflating: 1 (24)/Fichiers text/514538, 01-09-2021, Uni, $.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 02-08-2021, Uni, $$$.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 05-07-2021, Uni,$.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 12-07-2021, Uni.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 14-07-2021, Uni.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 21-07-2021, Uni, Ti,$.dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 23-07-2021, Uni,$.txt
#   inflating: 1 (24)/Fichiers text/514538, 30-06-2021, Uni,Ti,dat.txt
#   inflating: 1 (24)/Fichiers text/514538, 30-07-2021, Uni,$.dat.txt
#   inflating: 1 (25)/525847.xlsx
#   inflating: 1 (25)/Fichiers text/525847, 28-02-2020,Uni,$.txt
#   inflating: 1 (25)/Fichiers text/526847, 08-11-2019,Uni, Ti,$.txt
#   inflating: 1 (25)/Fichiers text/526847, 21-02-2020,Uni,$.txt
#   inflating: 1 (25)/Fichiers text/526847, 24-02-2020,Uni,$.txt
#   inflating: 1 (25)/Fichiers text/526847, 26-02-2020,Uni,$.txt
#   inflating: 1 (25)/Fichiers text/526847,06-11-2019,Uni, Ti,-.txt
#   inflating: 1 (25)/Fichiers text/526847,13-11-2019,Uni,$.txt
#   inflating: 1 (26)/537723.xlsx
#   inflating: 1 (26)/Fichiers text/537723, 04-11-2019,BiF.txt
#   inflating: 1 (26)/Fichiers text/537723, 18-10-2019,Uni,$.txt
#   inflating: 1 (26)/Fichiers text/537723, 23-12-2019,BiT,$.txt
#   inflating: 1 (26)/Fichiers text/537723, 28-10-2019,Uni,$.txt
#   inflating: 1 (26)/Fichiers text/537723,06-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,08-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,09-10-2019,Uni,$.txt
#   inflating: 1 (26)/Fichiers text/537723,13-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,15-10-2019,Uni,$.txt
#   inflating: 1 (26)/Fichiers text/537723,18-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,20-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,21-10-2019,Uni,$.txt
#   inflating: 1 (26)/Fichiers text/537723,22-11-2019,BiF,$.txt
#   inflating: 1 (26)/Fichiers text/537723,25-10-2019,Uni.txt
#   inflating: 1 (26)/Fichiers text/537723,27-11-2019,BiT,ti.txt
#   inflating: 1 (26)/Fichiers text/537723,27-12-2019,BiT,$.txt
#   inflating: 1 (26)/Fichiers text/537723,30-10-2019,Uni,$.txt
#   inflating: 1 (27)/640178.xlsx
#   inflating: 1 (27)/Fichiers text/640178, 16-11-2020, Uni,,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 18-11-2020, Uni,,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 20-11-2020, Uni,,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 23-11-2020, Uni,,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 25-11-2020, Uni,,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 26-10-2020, Uni, Ti,$.dat.txt
#   inflating: 1 (27)/Fichiers text/640178, 28-10-2020, Uni,$.dat.txt
#   inflating: 1 (28)/674119.xlsx
#   inflating: 1 (28)/Fichiers text/674119, 02-12-2020,Uni,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 04-12-2020,Uni,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 09-12-2020,Ti-1, BiF,$.txt
#   inflating: 1 (28)/Fichiers text/674119, 09-12-2020,Ti-2, BiF,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 11-12-2020,BiF,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 25-11-2020,Uni,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 27-11-2020,Uni,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119, 30-11-2020,Uni,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119,23-11-2020,Uni,Ti-EEG1invalid.dat.txt
#   inflating: 1 (28)/Fichiers text/674119,28-12-2020,BiF-1,-.txt
#   inflating: 1 (28)/Fichiers text/674119,28-12-2020,BiF-2,$.dat.txt
#   inflating: 1 (28)/Fichiers text/674119,30-12-2020,BiF,$.dat.txt
#   inflating: 1 (29)/685561.xlsx
#   inflating: 1 (29)/Fichiers text/685561, 02-03-2020,Uni,$.txt
#   inflating: 1 (29)/Fichiers text/685561, 05-08-2020,BiF,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 10-08-2020,BiF,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 13-07-2020,Uni,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 14-02-2020, Ti,-,Uni.txt
#   inflating: 1 (29)/Fichiers text/685561, 17-02-2020, Ti,Uni,.txt
#   inflating: 1 (29)/Fichiers text/685561, 17-07-2020,Uni,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 19-02-2020,Uni.txt
#   inflating: 1 (29)/Fichiers text/685561, 20-07-2020, Uni.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 21-02-2020,Uni.txt
#   inflating: 1 (29)/Fichiers text/685561, 22-07-2020, Ti, 1,BiF,-.txt
#   inflating: 1 (29)/Fichiers text/685561, 22-07-2020, Ti, 2,BiF,-.txt
#   inflating: 1 (29)/Fichiers text/685561, 26-07-2020, Ti, 1, BiF,-.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 26-07-2020,Ti,2,BiF,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 27-07-2020,BiF.dat.txt
#   inflating: 1 (29)/Fichiers text/685561, 29-07-2020,BiF,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,03-08-2020,BiF,1,-.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,03-08-2020,BiF,2,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,04-03-2020,Uni.txt
#   inflating: 1 (29)/Fichiers text/685561,10-07-2020,Ti,1,-,Uni.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,10-07-2020,Ti,2, Uni.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,15-07-2020,Uni,$.dat.txt
#   inflating: 1 (29)/Fichiers text/685561,24-02-2020,Uni,$.txt
#   inflating: 1 (29)/Fichiers text/685561,26-02-2020,Uni.txt
#   inflating: 1 (29)/Fichiers text/685561,28-02-2020,Uni.txt
#   inflating: 1 (1)/135866.xlsx
#   inflating: 1 (1)/Fichiers text/135866, 01-09-2021, BiT,$.dat.txt
#   inflating: 1 (1)/Fichiers text/135866, 04-08-2021, BiT,$.dat.txt
#   inflating: 1 (1)/Fichiers text/135866, 07-07-2021, BiT.dat.txt
#   inflating: 1 (1)/Fichiers text/135866, 11-06-2021, BiT,$.dat.txt
#   inflating: 1 (1)/Fichiers text/135866, 19-05-2021, BiT-1,$.dat.txt
#   inflating: 1 (1)/Fichiers text/135866, 19-05-2021, BiT-2,$.dat.txt
#   inflating: 1 (2)/170894.xlsx
#   inflating: 1 (2)/Fichiers text/170894, 01-02-2021,1,Uni,-.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 01-02-2021,2,Uni,$.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 02-06-2021, Uni.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 07-05-2021, Uni-1, -.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 07-05-2021, Uni-2, $.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 08-09-2021,Uni,$.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 10-05-2021, Uni.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 11-08-2021, Uni,0.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 12-07-2021,Uni.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 16-06-2021, Uni.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 21-05-2021, Uni.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 22-01-2021,Uni, Ti-1,-.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 22-01-2021,Uni, Ti-2,-.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 22-01-2021,Uni, Ti-3,-.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 27-01-2021, Uni, Ti-1,-.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 27-01-2021,Uni, Ti-2,$.dat.txt
#   inflating: 1 (2)/Fichiers text/170894, 29-01-2021,Uni,$.dat.txt
#   inflating: 1 (3)/191007.xlsx
#   inflating: 1 (3)/Fichiers text/191007,09-10-2019,BiT,$.txt
#   inflating: 1 (4)/201575.xlsx
#   inflating: 1 (4)/Fichiers text/201575, 04-06-2021, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 04-12-2020,Uni,Ti,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 05-07-2021, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 07-05-2021, Uni,,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 07-12-2020,Uni,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 09-12-2020, Uni,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 10-05-2021, Uni, $.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 11-06-2021, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 11-12-2020, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 12-05-2021, Uni,,$-artefact EEG4.txt
#   inflating: 1 (4)/Fichiers text/201575, 14-07-2021, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 16-06-2021, Uni.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 17-05-2021, Uni,.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 19-05-2021, Uni,$,dat.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 21-05-2021, Uni-1.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 21-05-2021, Uni-2,$,dat..dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 23-06-2021, Uni,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 26-05-2021, Uni,$,dat..dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 28-05-2021, Uni,$,dat.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 29-01-2021, Uni,$.dat.txt
#   inflating: 1 (4)/Fichiers text/201575, 30-06-2021, Uni.dat.txt
#   inflating: 1 (5)/203961.xlsx
#   inflating: 1 (5)/Fichiers text/203961, 02-02-2021,Uni,$.dat.txt
#   inflating: 1 (5)/Fichiers text/203961, 04-08-2020,Uni,$.dat.txt
#   inflating: 1 (5)/Fichiers text/203961, 13-07-2020,Uni.dat.txt
#   inflating: 1 (5)/Fichiers text/203961, 20-07-2020, Uni.dat.txt
#   inflating: 1 (5)/Fichiers text/203961, 24-07-2020, Uni,$.dat.txt
#   inflating: 1 (5)/Fichiers text/203961, 27-07-2020,Uni,$.txt
#   inflating: 1 (5)/Fichiers text/203961, 29-07-2020, Uni, $.dat.txt
#   inflating: 1 (5)/Fichiers text/203961,10-07-2020, Ti,Uni.dat.txt
#   inflating: 1 (6)/218132.xlsx
#   inflating: 1 (6)/Fichiers text/218132, 02-09-2020, BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 06-08-2020,BiT,Ti.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 12-08-2020, BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132, 17-08-2020,BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 19-08-2020, BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 21-09-2020,BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 21-10-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132, 23-08-2020, BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 25-09-2020, BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 26-08-2020,BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132, 26-11-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132, 28-10-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132, 31-08-2020,BiT,$.dat.txt
#   inflating: 1 (6)/Fichiers text/218132,05-11-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,06-01-2020,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,12-11-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,15-10-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,17-02-2020,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,19-11-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,20-01-2020,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,23-12-2019,BiT,$.txt
#   inflating: 1 (6)/Fichiers text/218132,30-12-2019,BiT,$.txt
#   inflating: 1 (7)/218957.xlsx
#   inflating: 1 (7)/Fichiers text/218957, 21-06-2021, BiT, Ti-1,-.txt
#   inflating: 1 (7)/Fichiers text/218957, 21-06-2021, BiT, Ti-2,-.txt
#   inflating: 1 (7)/Fichiers text/218957, 21-06-2021, BiT, Ti-3,-.txt
#   inflating: 1 (7)/Fichiers text/218957, 21-06-2021, BiT, Ti-4,-.txt
#   inflating: 1 (7)/Fichiers text/218957, 23-06-2021, BiT, Ti-1,-.dat.txt
#   inflating: 1 (7)/Fichiers text/218957, 23-06-2021, BiT, Ti-2.dat.txt
#   inflating: 1 (8)/227193.xlsx
#   inflating: 1 (8)/Fichiers text/227193,07-10--2020,BiF,$.dat.txt
#   inflating: 1 (8)/Fichiers text/227193,09-10-2020,BiF,$.dat.txt
#   inflating: 1 (8)/Fichiers text/227193,14-10-2020,BiF,$.dat.txt
#   inflating: 1 (8)/Fichiers text/227193,28-09-2020,BiF,Ti,$.dat.txt
#   inflating: 1 (8)/Fichiers text/227193,30-09-2020,BiF,$.dat.txt
#   inflating: 1 (9)/234300.xlsx
#   inflating: 1 (9)/Fichiers text/234300, 05-07-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 07-10-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 09-06-2021,BiT,$$$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 11-01-2021,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 16-04-2021,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 16-08-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 26-02-2021, BiT, $, artefact EEG4.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 28-12-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 29-04-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300, 30-08-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,02-02-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,02-04-2021,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,02-08-2021,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,02-09-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,04-09-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,05-11-2019,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,09-09-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,09-10-2019,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,09-12-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,12-05-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,13-01-2020,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,14-09-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,16-09-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,17-02-2020,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,18-11-2020,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,19-07-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,19-11-2019,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,21-06-2021,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,21-10-2019,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,25-05-2021, BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234300,26-02-2020,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234300,30-12-2019,BiT,$.txt
#   inflating: 1 (9)/Fichiers text/234330, 28-10-2020,BiT,$.dat.txt
#   inflating: 1 (9)/Fichiers text/234400, 11-03-2020,BiT,$.txt
#   inflating: 1 (10)/245446.xlsx
#   inflating: 1 (10)/Fichiers text/245446, 02-06-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 03-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 05-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 07-06-2021, BiT,$$$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 10-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 12-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 17-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 21-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 22-01-2021, BiT,Ti-2,-.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 22-01-2021, BiT,Ti-3,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 22-01-2021,BiT,Ti-1,-.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 26-04-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 26-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 28-04-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 28-05-2021, BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446, 31-05-2021, BiT,.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,01-02-2021,BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,23-04-2021,BiT,$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,25-01-2021,BiT,$dat.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,26-03-2021,BiT,$$$.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,27-01-2021,BiT,$dat.dat.txt
#   inflating: 1 (10)/Fichiers text/245446,29-01-2021,BiT,$.dat.txt
#   inflating: 1 (11)/258322.xlsx
#   inflating: 1 (11)/Fichiers text/258322,08-09-2021,Uni, Ti,-, arteefacts.dat.txt

# %%
# %cd ..
# Out:
# /content/gdrive/My Drive

# %%
#2_channels
# %cd /content/gdrive/My Drive/Sajjad_cloned_ready
# !unzip 2_Channels.zip
# %cd Données-Copie-Sept 2020_2_channel
# Out:
# /content/gdrive/My Drive/Sajjad_cloned_ready
# Archive:  2_Channels.zip
# replace Données-Copie-Sept 2020_2_channel/191007/191007,09-10-2019,BiT,$.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Données-Copie-Sept 2020_2_channel/191007/191007,09-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/191007/191007.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/203961/203961.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 04-08-2020,Uni,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 13-07-2020,Uni.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 20-07-2020, Uni.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 24-07-2020, Uni,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 27-07-2020, Uni$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961, 29-07-2020, Uni, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers dat/203961,10-07-2020,Uni.dat
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 04-08-2020,Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 13-07-2020,Uni.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 20-07-2020, Uni.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 24-07-2020, Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 27-07-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/203961/Fichiers texte/203961, 29-07-2020, Uni, $.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/218132.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 02-09-2020, BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 06-08-2020,BiT,Ti.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 12-08-2020, BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 17-08-2020,BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 19-08-2020, BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 23-08-2020, BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 26-08-2020,BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 26-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132, 31-08-2020,BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,05-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,06-01-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,12-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,17-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,19-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,20-01-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,23-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers dat/218132,30-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 02-09-2020, BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 06-08-2020,BiT,Ti.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 12-08-2020, BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 17-08-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 19-08-2020, BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 21-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 23-08-2020, BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 26-08-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 26-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 28-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132, 31-08-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,05-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,06-01-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,12-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,15-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,17-02-2020,BiT,.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,19-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,20-01-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,23-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/218132/Fichiers text/218132,30-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/234300.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,02-09-2020,BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,04-09-2020,BiT,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,05-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,13-01-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,17-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,19-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,26-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234300,30-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers dat/234400, 11-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,02-09-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,04-09-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,05-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,09-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,13-01-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,17-02-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,19-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,21-10-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,26-02-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234300,30-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/234300/Fichiers text/234400, 11-03-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/325733/325733.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers dat/325733, 17-07-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers dat/325733, 20-07-2020, Uni, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers dat/325733,15-07-2020, Ti, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers texte/325733, 17-07-2020,Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers texte/325733, 20-07-2020, Uni, $.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/325733/Fichiers texte/325733,15-07-2020, Ti, Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/348655/348655.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/348655/Fichiers dat/348655,13-01-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/348655/Fichiers dat/348655,24-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/348655/Fichiers text/348655, 23-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/348655/Fichiers text/348655,13-01-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/348655/Fichiers text/348655,24-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/353456.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 11-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 13-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 18-03-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 20-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 24-01-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 25-03-2020, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers dat/353456, 27-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 11-03-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 13-03-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 18-03-2020,BiT.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 20-03-2020,BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 24-01-2020,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 25-03-2020, BiT,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/353456/Fichiers text/353456, 27-03-2020,BiT$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/354886/354886.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/354886/Fichiers dat/354886,06-01,2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/354886/Fichiers text/354886, 29-10-2019, BiF.txt
#   inflating: Données-Copie-Sept 2020_2_channel/354886/Fichiers text/354886,06-01,2020,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/369690.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 02-09-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 04-09-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 17-08-2020,BiF,Ti-1,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 17-08-2020,BiF,Ti-2,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 17-08-2020,Bif,Ti-3,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 19-08-2020,BiF,Ti-1,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 21-08-2020,BiF, Ti.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 23-08-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 26-08-2020,BiF,1.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 26-08-2020,BiF,2.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers dat/369690, 31-08-2020,BiF,Ti.dat
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 02-09-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 04-09-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 17-08-2020,Ti-1,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 17-08-2020,Ti-2,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 17-08-2020,Ti-3,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 19-08-2020,BiF,Ti-1,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 21-08-2020,BiF, Ti.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 24-08-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 26-08-2020,BiF,1.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 26-08-2020,BiF,2.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/369690/Fichiers text/369690, 31-08-2020,BiF,Ti.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/377765/377765.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/377765/desktop.ini
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers dat/37765,22-01-2020,$,2.dat
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers dat/377765,20-01-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers dat/377765,22-01-2020,-,1.dat
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers dat/desktop.ini
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers text/37765,22-01-2020,Uni,2,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers text/377765,20-01-2020,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/377765/Fichiers text/377765,22-01-2020,Uni,1,-.txt
#   inflating: Données-Copie-Sept 2020_2_channel/462293/465293.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers dat/465293, 29-10-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers dat/465293,23-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers dat/465293,25-11-2019, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers text/465293, 29-10-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers text/465293,23-12-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/462293/Fichiers text/465293,25-11-2019, BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/465293/465293.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/465293/Fichiers dat/465293, 19-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/465293/Fichiers dat/465293,20-01-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/465293/Fichiers text/465293, 19-02-2020,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/465293/Fichiers text/465293,20-01-2020,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/494811/494811.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/494811/Fichiers dat/494811,12-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/494811/Fichiers dat/494811,23-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/494811/Fichiers text/494811,12-11-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/494811/Fichiers text/494811,23-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/526847.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/525847, 28-02-2020, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847, 08-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847, 21-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847, 24-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847, 26-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847,06-11-2019,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers dat/526847,13-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/525847, 28-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847, 08-11-2019,Uni, Ti,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847, 21-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847, 24-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847, 26-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847,06-11-2019,Uni, Ti,-.txt
#   inflating: Données-Copie-Sept 2020_2_channel/526847/Fichiers text/526847,13-11-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/537723.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723, 04-11-2019.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723, 23-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,06-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,08-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,13-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,18-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,20-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,22-11-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,27-11-2019,ti.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,27-12-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers dat/537723,30-10-2019,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723, 04-11-2019,BiF.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723, 18-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723, 23-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723, 28-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,06-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,08-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,09-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,13-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,15-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,18-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,20-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,21-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,22-11-2019,BiF,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,25-10-2019,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,27-11-2019,BiT,ti.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,27-12-2019,BiT,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/537723/Fichiers text/537723,30-10-2019,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/685561.xlsx
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/658561,10-07-2020,Ti,''.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 02-03-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 05-08-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 10-08-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 13-07-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 14-02-2020, Ti,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 17-02-2020, Ti.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 17-07-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 19-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 20-07-2020, Uni.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 21-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 22-07-2020, Ti, 1,Bif,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 22-07-2020, Ti, 2,Bif,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 26-07-2020, Ti, 1, BiF,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 26-07-2020,Ti,2,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 27-07-2020,BiF.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561, 29-07-2020,BiF,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,03-08-2020,BiF,1,-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,03-08-2020,BiF,2,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,04-03-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,10-07-2020,Ti,',-.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,15-07-2020, $.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,24-02-2020,$.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,26-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers dat/685561,28-02-2020.dat
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/658561,10-07-2020,Ti,2, Uni.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 02-03-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 05-08-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 10-08-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 13-07-2020,Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 14-02-2020, Ti,-,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 17-02-2020, Ti,Uni,.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 17-07-2020,Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 19-02-2020,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 20-07-2020, Uni.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 21-02-2020,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 22-07-2020, Ti, 1,Bif,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 22-07-2020, Ti, 2,Bif,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 26-07-2020, Ti, 1, BiF,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 26-07-2020,Ti,2,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 27-07-2020,BiF.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561, 29-07-2020,BiF,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,03-08-2020,BiF,1,-.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,03-08-2020,BiF,2,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,04-03-2020,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,10-07-2020,Ti,1,-,Uni.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,15-07-2020,Uni,$.dat.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,24-02-2020,Uni,$.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,26-02-2020,Uni.txt
#   inflating: Données-Copie-Sept 2020_2_channel/685561/Fichiers texte/685561,28-02-2020,Uni.txt
# /content/gdrive/My Drive/Sajjad_cloned_ready/Données-Copie-Sept 2020_2_channel

# %% [markdown]
# #Body of EEG smart reader

# %%
#Extract the information of an EEG file from the excel file
def is_date(string, fuzzy=False):
   
    try: 
        parse(string, fuzzy=fuzzy)
        return True

    except ValueError:
        return False

def Date(List):
  for i in List:
    if is_date(i):
      return i
          
def get_patient_id(Str):

  for i in nltk.tokenize.wordpunct_tokenize(Str):
    if i.isdigit():
        if len(i)==6:
          return(i)
        elif len(i)>6:
          print('The Id number is incorrect for  file name:',Str) 
          print("Please make shure that the patient's id should be a six digits number")      

               
def EEG_reader(path):
  a = pd.read_fwf(path , skiprows=2, header=None).drop(0, axis=0)
  b = pd.read_csv(path , skiprows=2, header=None, sep='\t').drop(0, axis=0).drop(0, axis=1)
  if a.shape[1]>1:
    return a
  if b.shape[1]>1:
    return b
  # if a.shape[1] + b.shape[1]<=2:
  #   raise Exception('The EEG file at {} has a shape or encoding error. make sure the encoding is Utf-8'.format(path))

# %% [markdown]
# dev

# %%
def cols(path):
  a = list(pd.read_fwf(path , header=None).drop(0, axis=0).iloc[1].values)
  if 'EEG0' in a or 'EEG1' in a or 'EEG2' in a or 'EEG3' in a:
    for i in a:
      if i.__class__ != str:
        a.remove(i)
    if a[-1].__class__ != str:
        a.remove(a[-1])     
    return a
  else:
    b= list(pd.read_csv(path,  header=None, sep='\t').drop(0, axis=0).drop(0, axis=1).iloc[0].values)
    if 'EEG0' in b or 'EEG1' in b or 'EEG2' in b or 'EEG3' in b:
      for i in b:
        if i.__class__ != str:
          b.remove(i)
      if b[-1].__class__ != str:
        b.remove(b[-1])      
      return b 
    else:
      raise ValueError('File in path: {} column is corrupted'.format(path)) 
# Writes the informention from excel file along with the EEG raw data into a dataframe.
# itretates over the whole EEG folders
n =30 # Number of EEG data folders
EEGs= []  # Will be the EEG stack
# cols = ['EEG1', 'EEG1', 'EEG2', 'EEG4', 'Site', 'Phase', 'Durée clinique ', 'Durée EEG', 'Qualité clinique',
#  'Adranergie', 'Qualité Aplatissement', 'Patho', 'Age', 'Sexe', 'Charge', 'Ti vs Tt', 'Anesthésiant', 'Qualité EEG']
# cols1 = ['EEG1', 'EEG1', 'Site', 'Phase', 'Durée clinique ', 'Durée EEG', 'Qualité clinique',
#  'Adranergie', 'Qualité Aplatissement', 'Patho', 'Age', 'Sexe', 'Charge', 'Ti vs Tt', 'Anesthésiant', 'Qualité EEG'] 

path_txt = glob.iglob('/content/gdrive/My Drive/Sajjad_cloned_ready/**/*.txt', recursive=True)
path_xls = glob.iglob('/content/gdrive/My Drive/Sajjad_cloned_ready/**/*.xlsx', recursive=True)
Path_xls = []
Path_txt = []
Txt = []
Xls = []
for i in path_txt:
  Path_txt.append(i)
for i in path_xls:
  Path_xls.append(i) 
for i in tqdm(Path_txt):
  Txt.append(EEG_reader(i))
for i in tqdm(Path_xls):
  Xls.append((i,pd.read_excel(i)))
  

duplicate = []
duplicate_names = None
for  i in range(len(Path_xls)):
  duplicate.append(Path_xls[i].split('/')[-1])
if len(duplicate)>=2:
  duplicate_names = True
else:
  duplicate_names = False

"___________________________________________________________________________________________"  
"___________________________________________________________________________________________"  
if duplicate_names == False:
  EEGs=[]
  c0=0
  c1=0
  for j in tqdm(Path_txt):
    for i in Xls: 
      try:
        Site = i[1] [i[1]['Date']==Date(j.split(',')).strip()]
      except:
        pass  
      if len(Site)>=1:
        EEG = Txt[Path_txt.index(j)]
        Site1 = Site.values
        try:
          for k in Site1:
            EEGs.append(pd.DataFrame(np.hstack([EEG.values, 
                                                np.vstack([k for i in range(EEG.shape[0])])]),columns=[*cols(j), *list(Site.columns)]))
            
        except:
          c1=Site 

"___________________________________________________________________________________________"  
"___________________________________________________________________________________________"   
if duplicate_names == True:
  print ("The Excel files' name  have duplicates")
  print(duplicate)
# Out:
#  99%|█████████▉| 427/431 [01:29<00:00,  4.77it/s]
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-7-324eaddd9a1d> in <module>()
#      39   Path_xls.append(i)
#      40 for i in tqdm(Path_txt):
# ---> 41   Txt.append(EEG_reader(i))
#      42 for i in tqdm(Path_xls):
#      43   Xls.append((i,pd.read_excel(i)))
#
# <ipython-input-6-d0507fc237de> in EEG_reader(path)
#      26
#      27 def EEG_reader(path):
# ---> 28   a = pd.read_fwf(path , skiprows=2, header=None).drop(0, axis=0)
#      29   b = pd.read_csv(path , skiprows=2, header=None, sep='\t').drop(0, axis=0).drop(0, axis=1)
#      30   if a.shape[1]>1:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, **kwds)
#     846     kwds["infer_nrows"] = infer_nrows
#     847     kwds["engine"] = "python-fwf"
# --> 848     return _read(filepath_or_buffer, kwds)
#     849
#     850
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1189                     'are "c", "python", or "python-fwf")'
#    1190                 )
# -> 1191             self._engine = klass(self.f, **self.options)
#    1192
#    1193     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    3782         self.colspecs = kwds.pop("colspecs")
#    3783         self.infer_nrows = kwds.pop("infer_nrows")
# -> 3784         PythonParser.__init__(self, f, **kwds)
#    3785
#    3786     def _make_reader(self, f):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2393         # Set self.data to something that can read lines.
#    2394         if hasattr(f, "readline"):
# -> 2395             self._make_reader(f)
#    2396         else:
#    2397             self.data = f
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_reader(self, f)
#    3791             self.comment,
#    3792             self.skiprows,
# -> 3793             self.infer_nrows,
#    3794         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, colspecs, delimiter, comment, skiprows, infer_nrows)
#    3678         if colspecs == "infer":
#    3679             self.colspecs = self.detect_colspecs(
# -> 3680                 infer_nrows=infer_nrows, skiprows=skiprows
#    3681             )
#    3682         else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in detect_colspecs(self, infer_nrows, skiprows)
#    3745         rows = self.get_rows(infer_nrows, skiprows)
#    3746         if not rows:
# -> 3747             raise EmptyDataError("No rows from which to infer column width")
#    3748         max_len = max(map(len, rows))
#    3749         mask = np.zeros(max_len + 1, dtype=int)
#
# EmptyDataError: No rows from which to infer column width

# %%
EEGs_Quad_Channel=[]
EEGs_Dual_Channel=[]
Outlyers=[]
c0=0
c1=0
for j in tqdm(Path_txt):
  for i in Xls: 
    try:
      Site = i[1][i[1]['Date']==Date(j.split(',')).strip()]
    except:
      Site  
    if get_patient_id(j)==get_patient_id(i[0]):
      EEG = Txt[Path_txt.index(j)]
      Site1 = Site.values
      for k in Site1:
        mat = pd.DataFrame(np.hstack([EEG.values, np.vstack([k for i in range(EEG.shape[0])])]),columns=[*['EEG{}'.format(i) for i in range(EEG.shape[1])], *list(Site.columns)]).dropna(axis = 1, how = 'all')
        
        try:                                    
          Sexe = i[1]['Sexe'].iloc[0]
          Age = i[1]['Age'].iloc[0]
          Patho = i[1]['Patho'].iloc[0]
          mat['Sexe'].iloc[0] = Sexe
          mat['Age'].iloc[0] = Age
          mat['Patho'].iloc[0] = Patho
        except:
          pass 
        if 'EEG1'in list(mat.columns) and 'EEG2'in list(mat.columns) and 'EEG3'  in list(mat.columns):
          EEGs_Quad_Channel.append(mat)
        if 'EEG0' in list(mat.columns) and 'EEG1' in list(mat.columns) and 'EEG2' not in list(mat.columns):
          EEGs_Dual_Channel.append(mat)
        if 'EEG1' in list(mat.columns) and 'EEG2' in list(mat.columns) and 'EEG3' not in list(mat.columns):
          EEGs_Dual_Channel.append(mat)
        if 'EEG0'not in list(mat.columns) and 'EEG1'not in list(mat.columns) and 'EEG2' not in list(mat.columns):
          Outlyers.append(mat) 
        if 'ECG'in list(mat.columns):
          Outlyers.append(mat)
# Out:
# 100%|██████████| 431/431 [00:00<00:00, 891832.77it/s]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-225a0418-4bfa-4352-a46f-4aebe70477c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-225a0418-4bfa-4352-a46f-4aebe70477c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 353456, 24-01-2020,BiT,$.txt to 353456, 24-01-2020,BiT,$.txt
# {'353456, 24-01-2020,BiT,$.txt': b'\r\nRaw Data \xb5V\r\n       EEG1       EEG2       EEG3       EEG4\r\n       -0.5       -4.3       -3.3       -4.0\r\n        3.0       -3.1       -1.9       -4.3\r\n        4.5       -2.1       -0.8       -3.5\r\n        4.8       -0.6       -0.3       -2.5\r\n        4.5        1.3        0.0       -1.6\r\n        3.1        2.1        0.0       -0.8\r\n        0.1        1.4       -0.6        0.3\r\n       -3.6       -0.5       -2.0        1.6\r\n       -6.9       -2.6       -3.3        3.0\r\n       -8.5       -4.1       -3.9        3.6\r\n       -8.0       -4.8       -3.8        3.0\r\n       -5.8       -4.9       -3.5        1.1\r\n       -3.6       -4.8       -3.6       -1.1\r\n       -3.0       -5.0       -4.1       -2.9\r\n       -3.4       -5.6       -4.5       -3.5\r\n       -3.3       -5.9       -4.1       -3.1\r\n       -2.1       -5.0       -3.0       -1.9\r\n       -1.0       -3.4       -1.4        0.0\r\n       -1.0       -2.1        0.0        1.8\r\n       -2.5       -2.0        0.6        2.5\r\n       -4.8       -3.1        0.4        2.1\r\n       -6.1       -5.0       -0.5        0.6\r\n       -5.8       -6.5       -1.5       -1.1\r\n       -3.8       -5.6       -1.9       -2.4\r\n       -0.8       -2.0       -1.4       -2.9\r\n        2.4        2.9       -0.3       -2.3\r\n        4.5        6.8        1.0       -0.6\r\n        5.1        8.4        1.9        1.3\r\n        4.4        8.1        2.3        2.6\r\n        2.9        7.0        2.4        3.4\r\n        1.3        5.8        2.4        3.5\r\n        0.5        5.3        2.8        3.1\r\n        1.3        5.9        3.5        2.1\r\n        3.0        7.0        3.9        0.8\r\n        4.5        7.6        3.4       -0.1\r\n        5.3        7.1        2.0       -0.1\r\n        5.4        5.5        0.5        0.5\r\n        4.6        3.3       -0.1        1.1\r\n        3.0        0.6        0.5        1.3\r\n        1.4       -2.0        1.8        0.4\r\n        0.8       -3.4        2.9       -1.1\r\n        1.3       -2.4        3.3       -2.4\r\n        2.9        1.3        2.6       -3.1\r\n        4.8        5.8        1.0       -3.5\r\n        5.0        8.5       -0.9       -3.5\r\n        2.6        7.6       -2.1       -3.3\r\n       -0.9        3.9       -2.1       -2.6\r\n       -3.0       -0.3       -0.8       -2.0\r\n       -2.5       -2.0        1.1       -2.0\r\n        0.1       -0.5        2.4       -2.3\r\n        3.6        3.3        2.6       -1.9\r\n        6.5        7.3        1.9       -0.5\r\n        7.8        9.4        0.8        1.3\r\n        7.0        8.6        0.0        2.5\r\n        4.4        5.6        0.1        3.3\r\n        1.5        2.3        1.1        3.9\r\n        0.6        0.8        2.8        4.5\r\n        2.6        2.4        4.1        4.8\r\n        6.5        5.9        4.5        4.5\r\n        9.8        8.1        3.9        3.8\r\n        9.9        6.6        2.4        2.3\r\n        5.9        1.6        0.6        0.1\r\n       -0.9       -5.0       -1.1       -1.6\r\n       -7.5      -10.8       -2.8       -2.5\r\n      -11.5      -13.1       -4.1       -2.4\r\n      -11.3      -11.0       -4.6       -1.3\r\n       -7.3       -6.3       -4.1        0.4\r\n       -1.5       -1.6       -3.4        1.9\r\n        3.8        1.6       -3.0        3.0\r\n        6.3        3.0       -3.3        3.5\r\n        4.0        1.4       -4.1        3.1\r\n       -2.8       -3.6       -5.5        2.0\r\n       -9.9      -10.0       -7.0        0.8\r\n      -12.5      -14.1       -8.0       -0.1\r\n       -9.0      -14.1       -8.0       -0.4\r\n       -2.3      -11.1       -7.1       -0.4\r\n        3.5       -7.5       -6.1       -0.5\r\n        5.5       -5.3       -6.0       -0.9\r\n        3.6       -4.5       -7.0       -1.3\r\n        0.0       -4.6       -8.4       -1.3\r\n       -3.0       -4.9       -9.1       -1.0\r\n        ...

# %%
tt=pd.DataFrame(EEG_reader('353456, 24-01-2020,BiT,$.txt').values.astype(float))
tt.columns=['EEG0', 'EEG1', 'EMG', 'ECG']

# %%
__builtins__.data_test=tt

# %% [markdown]
# #FFT

# %%
from scipy import fftpack
from sklearn.model_selection import train_test_split

# %%
# good_Quad =[EEGs_Quad_Channel[i] for i in range(len(EEGs_Quad_Channel)) if EEGs_Quad_Channel[i]['Qualité clinique'][0]=='+++']
# bad_Quad =[EEGs_Quad_Channel[i] for i in range(len(EEGs_Quad_Channel)) if EEGs_Quad_Channel[i]['Qualité clinique'][0]=='-']

# good_Dual =[EEGs_Dual_Channel[i] for i in range(len(EEGs_Dual_Channel)) if EEGs_Dual_Channel[i]['Qualité clinique'][0]=='+++']
# bad_Dual =[EEGs_Dual_Channel[i] for i in range(len(EEGs_Dual_Channel)) if EEGs_Dual_Channel[i]['Qualité clinique'][0]=='-']

# %%
# FFT_Quad_good = [fftpack.rfft(i['EEG0'].values[0:100]) for i in good_Quad]    
# FFT_Quad_bad = [fftpack.rfft(i['EEG0'].values[0:100]) for i in bad_Quad]   
# FFT_Dual_good = [fftpack.rfft(i['EEG0'].values[0:100]) for i in good_Dual]    
# FFT_Dual_bad = [fftpack.rfft(i['EEG0'].values[0:100]) for i in bad_Dual]   

# X_Dual = [*FFT_Dual_good, *FFT_Dual_bad]
# X_Quad = [*FFT_Quad_good, *FFT_Quad_bad]

# y_Dual =[*list(np.ones(len(X_Dual))),*list(np.ones(len(X_Dual)))]
# y_Quad =[*list(np.ones(len(X_Quad))),*list(np.ones(len(X_Quad)))]

# X_train_Quad, X_test_Quad, y_train_Quad, y_test_Quad = train_test_split(X_Quad, y_Quad, test_size=0.33, random_state=42)      
# X_train_Dual, X_test_Dual, y_train_Dual, y_test_Dual = train_test_split(X_Dual, y_Dual, test_size=0.33, random_state=42)

# %% [markdown]
# #Conditional_Variational Autoencoder (Part A)_Good_Quad_train dual_test

# %%
# !git clone https://github.com/joseffaghihi/Causal-fuzzy-CEVAE.git
# %cd Causal-fuzzy-CEVAE/ECT
# !unzip pyro.zip
# %cd pyro/pyro-dev
# !python setup.py install
import pyro

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import torch
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import entropy
import warnings
import logging

# %%
#The covariates data has 46 features
x = pd.read_csv("https://raw.githubusercontent.com/AMLab-Amsterdam/CEVAE/master/datasets/TWINS/twin_pairs_X_3years_samesex.csv")

#The outcome data contains mortality of the lighter and heavier twin
y = pd.read_csv("https://raw.githubusercontent.com/AMLab-Amsterdam/CEVAE/master/datasets/TWINS/twin_pairs_Y_3years_samesex.csv")

#The treatment data contains weight in grams of both the twins
t = pd.read_csv("https://raw.githubusercontent.com/AMLab-Amsterdam/CEVAE/master/datasets/TWINS/twin_pairs_T_3years_samesex.csv")

lighter_columns = ['pldel', 'birattnd', 'brstate', 'stoccfipb', 'mager8',
       'ormoth', 'mrace', 'meduc6', 'dmar', 'mplbir', 'mpre5', 'adequacy',
       'orfath', 'frace', 'birmon', 'gestat10', 'csex', 'anemia', 'cardiac',
       'lung', 'diabetes', 'herpes', 'hydra', 'hemo', 'chyper', 'phyper',
       'eclamp', 'incervix', 'pre4000', 'preterm', 'renal', 'rh', 'uterine',
       'othermr', 'tobacco', 'alcohol', 'cigar6', 'drink5', 'crace',
       'data_year', 'nprevistq', 'dfageq', 'feduc6', 'infant_id_0',
       'dlivord_min', 'dtotord_min', 'bord_0',
       'brstate_reg', 'stoccfipb_reg', 'mplbir_reg']
heavier_columns = [ 'pldel', 'birattnd', 'brstate', 'stoccfipb', 'mager8',
       'ormoth', 'mrace', 'meduc6', 'dmar', 'mplbir', 'mpre5', 'adequacy',
       'orfath', 'frace', 'birmon', 'gestat10', 'csex', 'anemia', 'cardiac',
       'lung', 'diabetes', 'herpes', 'hydra', 'hemo', 'chyper', 'phyper',
       'eclamp', 'incervix', 'pre4000', 'preterm', 'renal', 'rh', 'uterine',
       'othermr', 'tobacco', 'alcohol', 'cigar6', 'drink5', 'crace',
       'data_year', 'nprevistq', 'dfageq', 'feduc6',
       'infant_id_1', 'dlivord_min', 'dtotord_min', 'bord_1',
       'brstate_reg', 'stoccfipb_reg', 'mplbir_reg']

data = []

for i in range(len(t.values)):

    #select only if both <=2kg
    if t.iloc[i].values[1]>=2000 or t.iloc[i].values[2]>=2000:
        continue

    this_instance_lighter = list(x.iloc[i][lighter_columns].values)
    this_instance_heavier = list(x.iloc[i][heavier_columns].values)

    #adding weight
    this_instance_lighter.append(t.iloc[i].values[1])
    this_instance_heavier.append(t.iloc[i].values[2])

    #adding treatment, is_heavier
    this_instance_lighter.append(0)
    this_instance_heavier.append(1)

    #adding the outcome
    this_instance_lighter.append(y.iloc[i].values[1])
    this_instance_heavier.append(y.iloc[i].values[2])
    data.append(this_instance_lighter)
    data.append(this_instance_heavier)

cols = [ 'pldel', 'birattnd', 'brstate', 'stoccfipb', 'mager8',
       'ormoth', 'mrace', 'meduc6', 'dmar', 'mplbir', 'mpre5', 'adequacy',
       'orfath', 'frace', 'birmon', 'gestat10', 'csex', 'anemia', 'cardiac',
       'lung', 'diabetes', 'herpes', 'hydra', 'hemo', 'chyper', 'phyper',
       'eclamp', 'incervix', 'pre4000', 'preterm', 'renal', 'rh', 'uterine',
       'othermr', 'tobacco', 'alcohol', 'cigar6', 'drink5', 'crace',
       'data_year', 'nprevistq', 'dfageq', 'feduc6',
       'infant_id', 'dlivord_min', 'dtotord_min', 'bord',
       'brstate_reg', 'stoccfipb_reg', 'mplbir_reg','wt','treatment','outcome']
__builtins__.cols=cols       
df = pd.DataFrame(columns=cols,data=data)

df = df.astype({"treatment":'bool'}, copy=False) #explicitly assigning treatment column as boolean

df.fillna(value=df.mean(),inplace=True)    #filling the missing values
df.fillna(value=df.mode().loc[0],inplace=True)

data_1 = df[df["treatment"]==1]
data_0 = df[df["treatment"]==0]
print(np.mean(data_1["outcome"]))
print(np.mean(data_0["outcome"]))
print("ATE", np.mean(data_1["outcome"])- np.mean(data_0["outcome"]))

# %%
perm = [i for i in range(51)]
__builtins__.cols=perm + ['treatment' , 'y_factual']
df.columns = __builtins__.cols
df.dataframeName = 'data'
__builtins__.datar=df
df = pd.concat([df]*1, ignore_index=True)
__builtins__.data=df
#=================================================#
X = df[perm].values
treatment = df['treatment'].values
y = df['y_factual'].values
__builtins__.itr, __builtins__.ite = train_test_split(np.arange(X.shape[0]), test_size=0.2, random_state=1)
X_train, treatment_train, y_train =X[itr], treatment[itr], y[itr]
X_val, treatment_val, y_val = X[ite], treatment[ite], y[ite]
__builtins__.X_train=X_train
__builtins__.treatment_train=treatment_train
__builtins__.y_train=y_train
__builtins__.X_val=X_val
__builtins__.treatment_val=treatment_val
__builtins__.y_val=y_val
__builtins__.outcome_dist = "normal"
__builtins__.latent_dim = 20
__builtins__.hidden_dim = 300
__builtins__.num_epochs = 5
__builtins__.batch_size = 1000
__builtins__.learning_rate = 0.001
__builtins__.learning_rate_decay = 0.01
__builtins__.num_layers =2
#====================================================+

__builtins__.L=[__builtins__.outcome_dist, __builtins__.latent_dim, __builtins__.hidden_dim,
  __builtins__.num_epochs, __builtins__.batch_size, __builtins__.learning_rate,
  __builtins__.learning_rate_decay, __builtins__.num_layers]

__builtins__.RuleDefiner="""[min(1-b,a),,  max(1-b,a),, max(min(1-a,1-b),b) ,, 1 - a - b + 2*a*b +b**2- a*b**2,,    min(1, (max (0, 1-a-b) + b)) ,, max(1-a, min (a,b)) ,, 1-a + b*a**2 ,, min(1,1-a+b)]"""

# %%
# !git clone https://github.com/pyro-ppl/pyro.git
# %cd pyro
# !python setup.py install
import pyro
import torch
# !pip install visdom
# %cd examples/vae/utils
# !python custom_mlp.py    
# !python vae_plots.py
# !python __init__.py

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
df=__builtins__.data
X = df
y = df['y_factual']
X = X.values
y = torch.tensor(y.values)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = torch.tensor(scaler.transform(X_train)).float()
X_test = torch.tensor(scaler.transform(X_test)).float()


class PimaIndiansDiabetes(Dataset):
  def __init__(self, X, y):
      self.X = X
      self.y = y
      self.len = len(self.X)
  def __getitem__(self, index):
      return self.X[index], self.y[index]
  def __len__(self):
      return self.len


train_data = PimaIndiansDiabetes(X_train, y_train)
test_data = PimaIndiansDiabetes(X_test, y_test)      
train_loader = DataLoader(dataset=train_data, batch_size=64, shuffle=True, drop_last=True)
test_loader = DataLoader(dataset=test_data, batch_size=64, shuffle=True, drop_last=True)
import argparse
import numpy as np
import torch
import torch.nn as nn
import visdom

import pyro
import pyro.distributions as dist
from pyro.infer import SVI, JitTrace_ELBO, Trace_ELBO
from pyro.optim import Adam


# define the PyTorch module that parameterizes the
# diagonal gaussian distribution q(z|x)
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(53, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 53)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale


# define the PyTorch module that parameterizes the
# observation likelihood p(x|z)
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 53)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = torch.sigmoid(self.fc21(hidden))
        return loc_img


# define a PyTorch module for the VAE
class VAE(nn.Module):
    
    def __init__(self, z_dim=53, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = torch.zeros(x.shape[0], self.z_dim, dtype=x.dtype, device=x.device)
            z_scale = torch.ones(x.shape[0], self.z_dim, dtype=x.dtype, device=x.device)
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder.forward(z)
            # score against actual images (with relaxed Bernoulli values)
            pyro.sample(
                "obs",
                dist.Bernoulli(loc_img, validate_args=False).to_event(1),
                obs=x.reshape(-1, 53),
            )
            # return the loc so we can visualize it later
            return loc_img

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img


def main(args):
    # clear param store
    pyro.clear_param_store()

    # setup MNIST data loaders
    # train_loader, test_loader
    # train_loader, test_loader = setup_data_loaders(
    #     MNIST, use_cuda=args.cuda, batch_size=253
    # )
    # print(train_loader.dataset)
    # setup the VAE
    vae = VAE(use_cuda=args.cuda)

    # setup the optimizer
    adam_args = {"lr": args.learning_rate}
    optimizer = Adam(adam_args)

    # setup the inference algorithm
    elbo = JitTrace_ELBO() if args.jit else Trace_ELBO()
    svi = SVI(vae.model, vae.guide, optimizer, loss=elbo)

    # setup visdom for visualization
    if args.visdom_flag:
        vis = visdom.Visdom()

    train_elbo = []
    test_elbo = []
    # training loop
    for epoch in range(2):
        # initialize loss accumulator
        epoch_loss = 0.0
        # do a training epoch over each mini-batch x returned
        # by the data loader
        for x, _ in train_loader:
            # if on GPU put mini-batch into CUDA memory
            if args.cuda:
                x = x.cuda()
            # do ELBO gradient and accumulate loss
            epoch_loss += svi.step(x)

        # report training diagnostics
        normalizer_train = len(train_loader.dataset)
        total_epoch_loss_train = epoch_loss / normalizer_train
        train_elbo.append(total_epoch_loss_train)
        print(
            "[epoch %03d]  average training loss: %.4f"
            % (epoch, total_epoch_loss_train)
        )

        if epoch % args.test_frequency == 0:
            # initialize loss accumulator
            test_loss = 0.0
            # compute the loss over the entire test set
            for i, (x, _) in enumerate(test_loader):
                # if on GPU put mini-batch into CUDA memory
                if args.cuda:
                    x = x.cuda()
                # compute ELBO estimate and accumulate loss
                test_loss += svi.evaluate_loss(x)

                # pick three random test images from the first mini-batch and
                # visualize how well we're reconstructing them
                if i == 0:
                    if args.visdom_flag:
                        plot_vae_samples(vae, vis)
                        reco_indices = np.random.randint(0, x.shape[0], 3)
                        for index in reco_indices:
                            test_img = x[index, :]
                            reco_img = vae.reconstruct_img(test_img)
                            vis.image(
                                test_img.reshape(28, 28).detach().cpu().numpy(),
                                opts={"caption": "test image"},
                            )
                            vis.image(
                                reco_img.reshape(28, 28).detach().cpu().numpy(),
                                opts={"caption": "reconstructed image"},
                            )

            # report test diagnostics
            normalizer_test = len(test_loader.dataset)
            total_epoch_loss_test = test_loss / normalizer_test
            test_elbo.append(total_epoch_loss_test)
            print(
                "[epoch %03d]  average test loss: %.4f" % (epoch, total_epoch_loss_test)
            )

        if epoch == args.tsne_iter:
            mnist_test_tsne(vae=vae, test_loader=test_loader)
            plot_llk(np.array(train_elbo), np.array(test_elbo))

    return vae


if __name__ == "__main__":
    assert pyro.__version__.startswith("1.7.0")
    # parse command line arguments
    parser = argparse.ArgumentParser(description="parse args")
    parser.add_argument(
        "-n", "--num-epochs", default=101, type=int, help="number of training epochs"
    )
    parser.add_argument(
        "-tf",
        "--test-frequency",
        default=5,
        type=int,
        help="how often we evaluate the test set",
    )
    parser.add_argument(
        "-lr", "--learning-rate", default=1.0e-3, type=float, help="learning rate"
    )
    parser.add_argument(
        "--cuda", action="store_true", default=False, help="whether to use cuda"
    )
    parser.add_argument(
        "--jit", action="store_true", default=False, help="whether to use PyTorch jit"
    )
    parser.add_argument(
        "-visdom",
        "--visdom_flag",
        action="store_true",
        help="Whether plotting in visdom is desired",
    )
    parser.add_argument(
        "-i-tsne",
        "--tsne_iter",
        default=100,
        type=int,
        help="epoch when tsne visualization runs",
    )
    parser.add_argument('-f')
    args = parser.parse_args()

    model = main(args)

V=VAE()
d=np.random.random((53*400)).reshape((400,53))
V.decoder(torch.tensor(d).float())    

__builtins__.PartA = V.decoder(torch.tensor(d).float())

# %%
__builtins__.PartA = pd.DataFrame(__builtins__.PartA.detach().numpy())
__builtins__.PartA = pd.concat([__builtins__.PartA]*100, ignore_index=True)
__builtins__.PartA.columns=[i for  i in range(51)]+['treatment', 'y_factual']
perm= [i for  i in range(51)]
__builtins__.PartA['treatment'] = __builtins__.PartA['treatment'].apply(lambda x: 0 if x<= (__builtins__.PartA['treatment'].max()-__builtins__.PartA['treatment'].min())/2 else 1)
X_train = __builtins__.PartA[perm].values
treatment_train = __builtins__.PartA['treatment'].values
y_train = torch.Tensor(__builtins__.PartA['y_factual'].values)

# %% [markdown]
# #CEVAE(part B)_Good_Quad_train dual_test

# %%
import logging
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pyro
import pyro.distributions as dist
from pyro import poutine
from pyro.infer import SVI, Trace_ELBO
from pyro.infer.util import torch_item
from pyro.nn import PyroModule
from pyro.optim import ClippedAdam
from pyro.util import torch_isnan
logger = logging.getLogger(__name__)
import builtins
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import torch
from pyro.contrib.cevae import Cevae
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import entropy
import warnings
from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.propensity import ElasticNetPropensityModel
from causalml.metrics import *
from causalml.dataset import simulate_hidden_confounder
from causalml.inference.meta.utils import convert_pd_to_np


class FullyConnected(nn.Sequential):

    def __init__(self, sizes, final_activation=None):
        layers = []
        for in_size, out_size in zip(sizes, sizes[1:]):
            layers.append(nn.Linear(in_size, out_size))
            layers.append(nn.ELU())
        layers.pop(-1)
        if final_activation is not None:
            layers.append(final_activation)
        super().__init__(*layers)

    def append(self, layer):
        assert isinstance(layer, nn.Module)
        self.add_module(str(len(self)), layer)


class DistributionNet(nn.Module):

    @staticmethod
    def get_class(dtype):
        for cls in DistributionNet.__subclasses__():
            if cls.__name__.lower() == dtype + "net":
                return cls
        raise ValueError("dtype not supported: {}".format(dtype))


class BernoulliNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [1])

    def forward(self, x):
        logits = self.fc(x).squeeze(-1).clamp(min=-10, max=10)
        return (logits,)

    @staticmethod
    def make_dist(logits):
        return dist.Bernoulli(logits=logits)


class ExponentialNet(DistributionNet):
    
    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [1])

    def forward(self, x):
        scale = nn.functional.softplus(self.fc(x).squeeze(-1)).clamp(min=1e-3, max=1e6)
        rate = scale.reciprocal()
        return (rate,)

    @staticmethod
    def make_dist(rate):
        return dist.Exponential(rate)


class LaplaceNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        return loc, scale

    @staticmethod
    def make_dist(loc, scale):
        return dist.Laplace(loc, scale)


class NormalNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        return loc, scale

    @staticmethod
    def make_dist(loc, scale):
        return dist.Normal(loc, scale)


class StudentTNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])
        self.df_unconstrained = nn.Parameter(torch.tensor(0.0))

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        df = nn.functional.softplus(self.df_unconstrained).add(1).expand_as(loc)
        return df, loc, scale

    @staticmethod
    def make_dist(df, loc, scale):
        return dist.StudentT(df, loc, scale)


class DiagNormalNet(nn.Module):

    def __init__(self, sizes):
        assert len(sizes) >= 2
        self.dim = sizes[-1]
        super().__init__()
        self.fc = FullyConnected(sizes[:-1] + [self.dim * 2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., : self.dim].clamp(min=-1e2, max=1e2)
        scale = (
            nn.functional.softplus(loc_scale[..., self.dim :]).add(1e-3).clamp(max=1e2)
        )
        return loc, scale


class PreWhitener(nn.Module):


    def __init__(self, data):
        super().__init__()
        with torch.no_grad():
            loc = data.mean(0)
            scale = data.std(0)
            scale[~(scale > 0)] = 1.0
            self.register_buffer("loc", loc)
            self.register_buffer("inv_scale", scale.reciprocal())

    def forward(self, data):
        return (data - self.loc) * self.inv_scale


class Model(PyroModule):

    def __init__(self, config):
        self.latent_dim = config["latent_dim"]
        super().__init__()
        self.x_nn = DiagNormalNet(
            [config["latent_dim"]]
            + [config["hidden_dim"]] * config["num_layers"]
            + [config["feature_dim"]]
        )
        OutcomeNet = DistributionNet.get_class(config["outcome_dist"])
        # The y network is split between the two t values.
        self.y0_nn = OutcomeNet(
            [config["latent_dim"]] + [config["hidden_dim"]] * config["num_layers"]
        )
        self.y1_nn = OutcomeNet(
            [config["latent_dim"]] + [config["hidden_dim"]] * config["num_layers"]
        )
        self.t_nn = BernoulliNet([config["latent_dim"]])

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            z = pyro.sample("z", self.z_dist())
            x = pyro.sample("x", self.x_dist(z), obs=x)
            t = pyro.sample("t", self.t_dist(z), obs=t)
            y = pyro.sample("y", self.y_dist(t, z), obs=y)
        return y

    def y_mean(self, x, t=None):
        with pyro.plate("data", x.size(0)):
            z = pyro.sample("z", self.z_dist())
            x = pyro.sample("x", self.x_dist(z), obs=x)
            t = pyro.sample("t", self.t_dist(z), obs=t)
        return self.y_dist(t, z).mean

    def z_dist(self):
        return dist.Normal(0, 1).expand([self.latent_dim]).to_event(1)

    def x_dist(self, z):
        loc, scale = self.x_nn(z)
        return dist.Normal(loc, scale).to_event(1)

    def y_dist(self, t, z):
        # Parameters are not shared among t values.
        params0 = self.y0_nn(z)
        params1 = self.y1_nn(z)
        t = t.bool()
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return self.y0_nn.make_dist(*params)

    def t_dist(self, z):
        (logits,) = self.t_nn(z)
        return dist.Bernoulli(logits=logits)


class Guide(PyroModule):
    
    def __init__(self, config):
        self.latent_dim = config["latent_dim"]
        OutcomeNet = DistributionNet.get_class(config["outcome_dist"])
        super().__init__()
        self.t_nn = BernoulliNet([config["feature_dim"]])
        # The y and z networks both follow an architecture where the first few
        # layers are shared for t in {0,1}, but the final layer is split
        # between the two t values.
        self.y_nn = FullyConnected(
            [config["feature_dim"]]
            + [config["hidden_dim"]] * (config["num_layers"] - 1),
            final_activation=nn.ELU(),
        )
        self.y0_nn = OutcomeNet([config["hidden_dim"]])
        self.y1_nn = OutcomeNet([config["hidden_dim"]])
        self.z_nn = FullyConnected(
            [1 + config["feature_dim"]]
            + [config["hidden_dim"]] * (config["num_layers"] - 1),
            final_activation=nn.ELU(),
        )
        self.z0_nn = DiagNormalNet([config["hidden_dim"], config["latent_dim"]])
        self.z1_nn = DiagNormalNet([config["hidden_dim"], config["latent_dim"]])
    def Sample_buffer(self,*args, **kwargs):
      if __builtins__.temp.__class__==list:
        pass

      else:
        __builtins__.temp=[]  

      if kwargs['signal']==True:
        __builtins__.temp=[]

      elif len(__builtins__.temp)<100:
        __builtins__.temp.append(kwargs['data'])

      if  len(__builtins__.temp)==100:
        __builtins__.signal=True  
        __builtins__.temp=[] 
      return __builtins__.temp 

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            # The t and y sites are needed for prediction, and participate in
            # the auxiliary CEVAE loss. We mark them auxiliary to indicate they
            # do not correspond to latent variables during training.
            t = pyro.sample("t", self.t_dist(x), obs=t, infer={"is_auxiliary": True})
            y = pyro.sample("y", self.y_dist(t, x), obs=y, infer={"is_auxiliary": True})
            # The z site participates only in the usual ELBO loss.
            pyro.sample("z", self.z_dist(y, t, x))
            __builtins__.Trans_M_sample=pyro.sample("z_f", self.z_dist(y, t, x))
            # print(type(__builtins__.Trans_M_sample))
            self.Sample_buffer(data=__builtins__.Trans_M_sample, signal=None)
            logger.info('Sample: {}'.format(__builtins__.temp ))

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            t = pyro.sample("t", self.t_dist(x), obs=t, infer={"is_auxiliary": True})
            y = pyro.sample("y", self.y_dist(t, x), obs=y, infer={"is_auxiliary": True})
            pyro.sample("z", self.z_dist(y, t, x))

    def t_dist(self, x):
        (logits,) = self.t_nn(x)
        return dist.Bernoulli(logits=logits)

    def y_dist(self, t, x):
        hidden = self.y_nn(x)
        params0 = self.y0_nn(hidden)
        params1 = self.y1_nn(hidden)
        t = t.bool()
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return self.y0_nn.make_dist(*params)

    def z_dist(self, y, t, x):
        y_x = torch.cat([y.unsqueeze(-1), x], dim=-1)
        hidden = self.z_nn(y_x)
        params0 = self.z0_nn(hidden)
        params1 = self.z1_nn(hidden)
        t = t.bool().unsqueeze(-1)
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return dist.Normal(*params).to_event(1)


class TraceCausalEffect_ELBO(Trace_ELBO):
    def _differentiable_loss_particle(self, model_trace, guide_trace):
        # Construct -ELBO part.
        blocked_names = [
            name
            for name, site in guide_trace.nodes.items()
            if site["type"] == "sample" and site["is_observed"]
        ]
        blocked_guide_trace = guide_trace.copy()
        for name in blocked_names:
            del blocked_guide_trace.nodes[name]
        loss, surrogate_loss = super()._differentiable_loss_particle(
            model_trace, blocked_guide_trace
        )

        for name in blocked_names:
            log_q = guide_trace.nodes[name]["log_prob_sum"]
            loss = loss - torch_item(log_q)
            surrogate_loss = surrogate_loss - log_q

        return loss, surrogate_loss

    @torch.no_grad()
    def loss(self, model, guide, *args, **kwargs):
        return torch_item(self.differentiable_loss(model, guide, *args, **kwargs))


class CEVAEModel(nn.Module):

    def __init__(
        self,
        feature_dim,
        outcome_dist="bernoulli",
        latent_dim=20,
        hidden_dim=200,
        num_layers=3,
        num_samples=100,
    ):
        config = dict(
            feature_dim=feature_dim,
            latent_dim=latent_dim,
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            num_samples=num_samples,
        )
        for name, size in config.items():
            if not (isinstance(size, int) and size > 0):
                raise ValueError("Expected {} > 0 but got {}".format(name, size))
        config["outcome_dist"] = outcome_dist
        self.feature_dim = feature_dim
        self.num_samples = num_samples

        super().__init__()
        self.model = Model(config)
        self.guide = Guide(config)

    def fit(
        self,
        x,
        t,
        y,
        num_epochs=100,
        batch_size=100,
        learning_rate=1e-3,
        learning_rate_decay=0.1,
        weight_decay=1e-4,
        log_every=100,
    ):

        assert x.dim() == 2 and x.size(-1) == self.feature_dim
        assert t.shape == x.shape[:1]
        assert y.shape == y.shape[:1]
        self.whiten = PreWhitener(x)

        dataset = TensorDataset(x, t, y)
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
        logger.info("Training with {} minibatches per epoch".format(len(dataloader)))
        num_steps = num_epochs * len(dataloader)
        optim = ClippedAdam(
            {
                "lr": learning_rate,
                "weight_decay": weight_decay,
                "lrd": learning_rate_decay ** (1 / num_steps),
            }
        )
        svi = SVI(self.model, self.guide, optim, TraceCausalEffect_ELBO())
        losses = []
        for epoch in range(num_epochs):
            for x, t, y in dataloader:
                x = self.whiten(x)
                loss = svi.step(x, t, y, size=len(dataset)) / len(dataset)
                if log_every and len(losses) % log_every == 0:
                    logger.debug(
                        "step {: >5d} loss = {:0.6g}".format(len(losses), loss)
                    )
                assert not torch_isnan(loss)
                losses.append(loss)
        return losses

    @torch.no_grad()
    def ite(self, x, num_samples=None, batch_size=None):
        
        if num_samples is None:
            num_samples = self.num_samples
        if not torch._C._get_tracing_state():
            assert x.dim() == 2 and x.size(-1) == self.feature_dim

        dataloader = [x] if batch_size is None else DataLoader(x, batch_size=batch_size)
        # logger.info("Evaluating {} minibatches".format(len(dataloader)))
        result = []
        for x in dataloader:
            x = self.whiten(x)
            with pyro.plate("num_particles", num_samples, dim=-2):
                with poutine.trace() as tr, poutine.block(hide=["y", "t"]):
                    self.guide(x)
                with poutine.do(data=dict(t=torch.zeros(()))):
                    y0 = poutine.replay(self.model.y_mean, tr.trace)(x)
                with poutine.do(data=dict(t=torch.ones(()))):
                    y1 = poutine.replay(self.model.y_mean, tr.trace)(x)
            ite = (y1 - y0).mean(0)
            if not torch._C._get_tracing_state():
              pass
              # logger.debug("batch ate = {:0.6g}".format(ite.mean()))
            result.append(ite)
        return torch.cat(result)

    def to_script_module(self):
       
        self.train(False)
        fake_x = torch.randn(2, self.feature_dim)
        with pyro.validation_enabled(False):
            result = torch.jit.trace_module(self, {"ite": (fake_x,)}, check_trace=False)
        return result

#_________________________________________________________________________________

pyro_logger = logging.getLogger("pyro")
pyro_logger.setLevel(logging.DEBUG)
if pyro_logger.handlers:
    pyro_logger.handlers[0].setLevel(logging.DEBUG)


class CEVAE:
    def __init__(self, outcome_dist,latent_dim,hidden_dim,num_epochs,num_layers,
                 batch_size,learning_rate, learning_rate_decay,num_samples=100,weight_decay=1e-4):
    
        self.outcome_dist = __builtins__.outcome_dist
        self.latent_dim = __builtins__.latent_dim
        self.hidden_dim = __builtins__.hidden_dim
        self.num_epochs = __builtins__.num_epochs
        self.num_layers = __builtins__.num_layers
        self.batch_size = __builtins__.batch_size
        self.learning_rate = __builtins__.learning_rate
        self.learning_rate_decay = __builtins__.learning_rate_decay
        self.num_samples = num_samples
        self.weight_decay = weight_decay

    def fit(self, X,treatment,y, p=None):
        
        X, treatment, y = convert_pd_to_np(X, treatment, y)

        self.cevae = CEVAEModel(outcome_dist=self.outcome_dist,
                           feature_dim=X.shape[-1],
                           latent_dim=self.latent_dim,
                           hidden_dim=self.hidden_dim,
                           num_layers=self.num_layers)
        


        self.cevae.fit(x=torch.tensor(X, dtype=torch.float),
                       t=torch.tensor(treatment, dtype=torch.float),
                       y=torch.tensor(y, dtype=torch.float),
                       num_epochs=self.num_epochs,
                       batch_size=self.batch_size,
                       learning_rate=self.learning_rate,
                       learning_rate_decay=self.learning_rate_decay,
                       weight_decay=self.weight_decay)

    def weight_getter(self):
        return Cevae.parameters()

    def predict(self, X, treatment=None, y=None, p=None):
     
        return Cevae.ite(torch.tensor(X, dtype=torch.float),
                              num_samples=self.num_samples,
                              batch_size=self.batch_size)

    def fit_predict(self, X, treatment, y, p=None):
        
        self.fit(X, treatment, y)
        return self.predict(X)

########################################################################################## 
X_train = __builtins__.X_train
treatment_train = __builtins__.treatment_train
y_train = __builtins__.y_train 
########################################################################################## 

# def ite(*args, **kwargs):
  
warnings.filterwarnings('ignore')
logger = logging.getLogger('causalml')
logger.setLevel(logging.DEBUG)
plt.style.use('fivethirtyeight')
sns.set_palette('Paired')
plt.rcParams['figure.figsize'] = (12,8)


cevae = CEVAE(outcome_dist=__builtins__.outcome_dist,
              latent_dim=__builtins__.latent_dim,
              hidden_dim=__builtins__.hidden_dim,
              num_epochs=__builtins__.num_epochs,
              batch_size=__builtins__.batch_size,
              learning_rate=__builtins__.learning_rate,
              learning_rate_decay=__builtins__.learning_rate_decay,
              num_layers=__builtins__.num_layers)



# fit
losses = cevae.fit(X=torch.tensor(X_train, dtype=torch.float),
                  treatment=torch.tensor(treatment_train, dtype=torch.float),
                  y=torch.tensor(y_train, dtype=torch.float))

cevae.predict(X=torch.tensor(X_train, dtype=torch.float))
# Out:
# INFO 	 Training with 11 minibatches per epoch
# DEBUG 	 step  0 loss = 24.499660116708263
# DEBUG 	 step  1 loss = 23.863756322954757
# DEBUG 	 step  2 loss = 23.223253973304576
# DEBUG 	 step  3 loss = 23.350169247912717
# DEBUG 	 step  4 loss = 22.9465499870631
# DEBUG 	 step  5 loss = 21.966231563079493
# DEBUG 	 step  6 loss = 21.179062233534783
# DEBUG 	 step  7 loss = 21.396015773627962
# DEBUG 	 step  8 loss = 20.788145138431855
# DEBUG 	 step  9 loss = 19.94263699419413
# DEBUG 	 step  10 loss = 19.57912049651008
# DEBUG 	 step  11 loss = 19.35412776797373
# DEBUG 	 step  12 loss = 18.377978939648756
# DEBUG 	 step  13 loss = 18.491155586957426
# DEBUG 	 step  14 loss = 17.639502530884663
# DEBUG 	 step  15 loss = 17.09802178115252
# DEBUG 	 step  16 loss = 16.99286521804914
# DEBUG 	 step  17 loss = 15.935854614345725
# DEBUG 	 step  18 loss = 15.685318821714437
# DEBUG 	 step  19 loss = 14.654476893232449
# DEBUG 	 step  20 loss = 14.553763545389353
# DEBUG 	 step  21 loss = 14.277319659251564
# DEBUG 	 step  22 loss = 13.831940068176415
# DEBUG 	 step  23 loss = 12.627073427193384
# DEBUG 	 step  24 loss = 12.412927370354545
# DEBUG 	 step  25 loss = 12.489510390362033
# DEBUG 	 step  26 loss = 11.302421414660067
# DEBUG 	 step  27 loss = 10.56296432631441
# DEBUG 	 step  28 loss = 10.705184815306588
# DEBUG 	 step  29 loss = 10.488445434014602

# %%
#6,12,16,21 are high
cevae.weight_getter()
# Out:
#            0_freqc   1_freqc   2_freqc  ...  97_freqc  98_freqc  99_freqc
# 0_freqc   0.079020  0.070933  0.010917  ...  0.007354  0.079591  0.010087
# 1_freqc   0.085845  0.046462  0.067633  ...  0.034359  0.000392  0.087659
# 2_freqc   0.039125  0.019466  0.072152  ...  0.036507  0.094767  0.058293
# 3_freqc   0.098354  0.005722  0.099473  ...  0.094434  0.027829  0.012257
# 4_freqc   0.069671  0.097891  0.087020  ...  0.076682  0.017879  0.095185
# ...            ...       ...       ...  ...       ...       ...       ...
# 95_freqc  0.006557  0.063904  0.015442  ...  0.010585  0.066738  0.003251
# 96_freqc  0.068917  0.097479  0.054113  ...  0.082334  0.052332  0.003829
# 97_freqc  0.066471  0.030485  0.012323  ...  0.097647  0.090126  0.066181
# 98_freqc  0.009383  0.074771  0.013574  ...  0.004415  0.022290  0.057828
# 99_freqc  0.026634  0.014914  0.028454  ...  0.039057  0.030236  0.052633
#
# [100 rows x 100 columns]

# %% [markdown]
# #Conditional_Variational Autoencoder (Part A)_Bad_Quad_train dual_test

# %%
# !git clone https://github.com/pyro-ppl/pyro.git
# %cd pyro
# !python setup.py install
import pyro
import torch
# !pip install visdom
# %cd examples/vae/utils
# !python custom_mlp.py    
# !python vae_plots.py
# !python mnist_cached.py  
# !python __init__.py

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
df=__builtins__.data
X = df
y = df['y_factual']
X = X.values
y = torch.tensor(y.values)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = torch.tensor(scaler.transform(X_train)).float()
X_test = torch.tensor(scaler.transform(X_test)).float()


class PimaIndiansDiabetes(Dataset):
  def __init__(self, X, y):
      self.X = X
      self.y = y
      self.len = len(self.X)
  def __getitem__(self, index):
      return self.X[index], self.y[index]
  def __len__(self):
      return self.len


train_data = PimaIndiansDiabetes(X_train, y_train)
test_data = PimaIndiansDiabetes(X_test, y_test)      
train_loader = DataLoader(dataset=train_data, batch_size=64, shuffle=True, drop_last=True)
test_loader = DataLoader(dataset=test_data, batch_size=64, shuffle=True, drop_last=True)
import argparse
import numpy as np
import torch
import torch.nn as nn
import visdom
# from mnist_cached import MNISTCached as MNIST
# from mnist_cached import setup_data_loaders
# from vae_plots import mnist_test_tsne, plot_llk, plot_vae_samples

import pyro
import pyro.distributions as dist
from pyro.infer import SVI, JitTrace_ELBO, Trace_ELBO
from pyro.optim import Adam


# define the PyTorch module that parameterizes the
# diagonal gaussian distribution q(z|x)
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(53, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 53)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale


# define the PyTorch module that parameterizes the
# observation likelihood p(x|z)
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 53)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = torch.sigmoid(self.fc21(hidden))
        return loc_img


# define a PyTorch module for the VAE
class VAE(nn.Module):
    
    def __init__(self, z_dim=53, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = torch.zeros(x.shape[0], self.z_dim, dtype=x.dtype, device=x.device)
            z_scale = torch.ones(x.shape[0], self.z_dim, dtype=x.dtype, device=x.device)
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder.forward(z)
            # score against actual images (with relaxed Bernoulli values)
            pyro.sample(
                "obs",
                dist.Bernoulli(loc_img, validate_args=False).to_event(1),
                obs=x.reshape(-1, 53),
            )
            # return the loc so we can visualize it later
            return loc_img

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img


def main(args):
    # clear param store
    pyro.clear_param_store()

    # setup MNIST data loaders
    # train_loader, test_loader
    # train_loader, test_loader = setup_data_loaders(
    #     MNIST, use_cuda=args.cuda, batch_size=253
    # )
    # print(train_loader.dataset)
    # setup the VAE
    vae = VAE(use_cuda=args.cuda)

    # setup the optimizer
    adam_args = {"lr": args.learning_rate}
    optimizer = Adam(adam_args)

    # setup the inference algorithm
    elbo = JitTrace_ELBO() if args.jit else Trace_ELBO()
    svi = SVI(vae.model, vae.guide, optimizer, loss=elbo)

    # setup visdom for visualization
    if args.visdom_flag:
        vis = visdom.Visdom()

    train_elbo = []
    test_elbo = []
    # training loop
    for epoch in range(2):
        # initialize loss accumulator
        epoch_loss = 0.0
        # do a training epoch over each mini-batch x returned
        # by the data loader
        for x, _ in train_loader:
            # if on GPU put mini-batch into CUDA memory
            if args.cuda:
                x = x.cuda()
            # do ELBO gradient and accumulate loss
            epoch_loss += svi.step(x)

        # report training diagnostics
        normalizer_train = len(train_loader.dataset)
        total_epoch_loss_train = epoch_loss / normalizer_train
        train_elbo.append(total_epoch_loss_train)
        print(
            "[epoch %03d]  average training loss: %.4f"
            % (epoch, total_epoch_loss_train)
        )

        if epoch % args.test_frequency == 0:
            # initialize loss accumulator
            test_loss = 0.0
            # compute the loss over the entire test set
            for i, (x, _) in enumerate(test_loader):
                # if on GPU put mini-batch into CUDA memory
                if args.cuda:
                    x = x.cuda()
                # compute ELBO estimate and accumulate loss
                test_loss += svi.evaluate_loss(x)

                # pick three random test images from the first mini-batch and
                # visualize how well we're reconstructing them
                if i == 0:
                    if args.visdom_flag:
                        plot_vae_samples(vae, vis)
                        reco_indices = np.random.randint(0, x.shape[0], 3)
                        for index in reco_indices:
                            test_img = x[index, :]
                            reco_img = vae.reconstruct_img(test_img)
                            vis.image(
                                test_img.reshape(28, 28).detach().cpu().numpy(),
                                opts={"caption": "test image"},
                            )
                            vis.image(
                                reco_img.reshape(28, 28).detach().cpu().numpy(),
                                opts={"caption": "reconstructed image"},
                            )

            # report test diagnostics
            normalizer_test = len(test_loader.dataset)
            total_epoch_loss_test = test_loss / normalizer_test
            test_elbo.append(total_epoch_loss_test)
            print(
                "[epoch %03d]  average test loss: %.4f" % (epoch, total_epoch_loss_test)
            )

        if epoch == args.tsne_iter:
            mnist_test_tsne(vae=vae, test_loader=test_loader)
            plot_llk(np.array(train_elbo), np.array(test_elbo))

    return vae


if __name__ == "__main__":
    assert pyro.__version__.startswith("1.7.0")
    # parse command line arguments
    parser = argparse.ArgumentParser(description="parse args")
    parser.add_argument(
        "-n", "--num-epochs", default=101, type=int, help="number of training epochs"
    )
    parser.add_argument(
        "-tf",
        "--test-frequency",
        default=5,
        type=int,
        help="how often we evaluate the test set",
    )
    parser.add_argument(
        "-lr", "--learning-rate", default=1.0e-3, type=float, help="learning rate"
    )
    parser.add_argument(
        "--cuda", action="store_true", default=False, help="whether to use cuda"
    )
    parser.add_argument(
        "--jit", action="store_true", default=False, help="whether to use PyTorch jit"
    )
    parser.add_argument(
        "-visdom",
        "--visdom_flag",
        action="store_true",
        help="Whether plotting in visdom is desired",
    )
    parser.add_argument(
        "-i-tsne",
        "--tsne_iter",
        default=100,
        type=int,
        help="epoch when tsne visualization runs",
    )
    parser.add_argument('-f')
    args = parser.parse_args()

    model = main(args)

V=VAE()
d=np.random.random((53*400)).reshape((400,53))
V.decoder(torch.tensor(d).float())    

__builtins__.PartA = V.decoder(torch.tensor(d).float())
# Out:
# Collecting visdom
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
#      |████████████████████████████████| 676 kB 5.3 MB/s
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from visdom) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from visdom) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from visdom) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from visdom) (5.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from visdom) (22.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from visdom) (1.15.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.9 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from visdom) (7.1.2)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->visdom) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->visdom) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->visdom) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->visdom) (3.0.4)
# Building wheels for collected packages: visdom, torchfile
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=e8df335ed23034f976b3d4121672ffc99ce513cbe770bc4f3490be7183b8d701
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=968a8e14bc372af849b0750a6734c2e39b1c3a9e2edba7000f83efe4abf863b5
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# Installing collected packages: jsonpointer, websocket-client, torchfile, jsonpatch, visdom
# Successfully installed jsonpatch-1.32 jsonpointer-2.2 torchfile-0.1.0 visdom-0.1.8.9 websocket-client-1.2.3
# /content/Causal-fuzzy-CEVAE/Applied paper 2021-12-12/Arc2/20.21-12-11-main/pyro-dev/examples/vae/utils
# [epoch 000]  average training loss: -38.7632
# [epoch 000]  average test loss: -105.4118
# [epoch 001]  average training loss: -148.7124

# %%
__builtins__.PartA = pd.DataFrame(__builtins__.PartA.detach().numpy())
__builtins__.PartA = pd.concat([__builtins__.PartA], ignore_index=True)
__builtins__.PartA.columns=[i for  i in range(100)]+['treatment', 'y_factual']
perm= [i for  i in range(100)]
__builtins__.PartA['treatment'] = __builtins__.PartA['treatment'].apply(lambda x: 0 if x<= (__builtins__.PartA['treatment'].max()-__builtins__.PartA['treatment'].min())/2 else 1)
X_train = __builtins__.PartA[perm].values
treatment_train = __builtins__.PartA['treatment'].values
y_train = torch.Tensor(__builtins__.PartA['y_factual'].values)

# %% [markdown]
# #CEVAE(part B)_Bad_Quad_train dual_test

# %%
import logging
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pyro
import pyro.distributions as dist
from pyro import poutine
from pyro.infer import SVI, Trace_ELBO
from pyro.infer.util import torch_item
from pyro.nn import PyroModule
from pyro.optim import ClippedAdam
from pyro.util import torch_isnan
logger = logging.getLogger(__name__)
import builtins
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import torch
from pyro.contrib.cevae import Cevae
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import entropy
import warnings
from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.propensity import ElasticNetPropensityModel
from causalml.metrics import *
from causalml.dataset import simulate_hidden_confounder
from causalml.inference.meta.utils import convert_pd_to_np


class FullyConnected(nn.Sequential):

    def __init__(self, sizes, final_activation=None):
        layers = []
        for in_size, out_size in zip(sizes, sizes[1:]):
            layers.append(nn.Linear(in_size, out_size))
            layers.append(nn.ELU())
        layers.pop(-1)
        if final_activation is not None:
            layers.append(final_activation)
        super().__init__(*layers)

    def append(self, layer):
        assert isinstance(layer, nn.Module)
        self.add_module(str(len(self)), layer)


class DistributionNet(nn.Module):

    @staticmethod
    def get_class(dtype):
        for cls in DistributionNet.__subclasses__():
            if cls.__name__.lower() == dtype + "net":
                return cls
        raise ValueError("dtype not supported: {}".format(dtype))


class BernoulliNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [1])

    def forward(self, x):
        logits = self.fc(x).squeeze(-1).clamp(min=-10, max=10)
        return (logits,)

    @staticmethod
    def make_dist(logits):
        return dist.Bernoulli(logits=logits)


class ExponentialNet(DistributionNet):
    
    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [1])

    def forward(self, x):
        scale = nn.functional.softplus(self.fc(x).squeeze(-1)).clamp(min=1e-3, max=1e6)
        rate = scale.reciprocal()
        return (rate,)

    @staticmethod
    def make_dist(rate):
        return dist.Exponential(rate)


class LaplaceNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        return loc, scale

    @staticmethod
    def make_dist(loc, scale):
        return dist.Laplace(loc, scale)


class NormalNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        return loc, scale

    @staticmethod
    def make_dist(loc, scale):
        return dist.Normal(loc, scale)


class StudentTNet(DistributionNet):

    def __init__(self, sizes):
        assert len(sizes) >= 1
        super().__init__()
        self.fc = FullyConnected(sizes + [2])
        self.df_unconstrained = nn.Parameter(torch.tensor(0.0))

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., 0].clamp(min=-1e6, max=1e6)
        scale = nn.functional.softplus(loc_scale[..., 1]).clamp(min=1e-3, max=1e6)
        df = nn.functional.softplus(self.df_unconstrained).add(1).expand_as(loc)
        return df, loc, scale

    @staticmethod
    def make_dist(df, loc, scale):
        return dist.StudentT(df, loc, scale)


class DiagNormalNet(nn.Module):

    def __init__(self, sizes):
        assert len(sizes) >= 2
        self.dim = sizes[-1]
        super().__init__()
        self.fc = FullyConnected(sizes[:-1] + [self.dim * 2])

    def forward(self, x):
        loc_scale = self.fc(x)
        loc = loc_scale[..., : self.dim].clamp(min=-1e2, max=1e2)
        scale = (
            nn.functional.softplus(loc_scale[..., self.dim :]).add(1e-3).clamp(max=1e2)
        )
        return loc, scale


class PreWhitener(nn.Module):


    def __init__(self, data):
        super().__init__()
        with torch.no_grad():
            loc = data.mean(0)
            scale = data.std(0)
            scale[~(scale > 0)] = 1.0
            self.register_buffer("loc", loc)
            self.register_buffer("inv_scale", scale.reciprocal())

    def forward(self, data):
        return (data - self.loc) * self.inv_scale


class Model(PyroModule):

    def __init__(self, config):
        self.latent_dim = config["latent_dim"]
        super().__init__()
        self.x_nn = DiagNormalNet(
            [config["latent_dim"]]
            + [config["hidden_dim"]] * config["num_layers"]
            + [config["feature_dim"]]
        )
        OutcomeNet = DistributionNet.get_class(config["outcome_dist"])
        # The y network is split between the two t values.
        self.y0_nn = OutcomeNet(
            [config["latent_dim"]] + [config["hidden_dim"]] * config["num_layers"]
        )
        self.y1_nn = OutcomeNet(
            [config["latent_dim"]] + [config["hidden_dim"]] * config["num_layers"]
        )
        self.t_nn = BernoulliNet([config["latent_dim"]])

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            z = pyro.sample("z", self.z_dist())
            x = pyro.sample("x", self.x_dist(z), obs=x)
            t = pyro.sample("t", self.t_dist(z), obs=t)
            y = pyro.sample("y", self.y_dist(t, z), obs=y)
        return y

    def y_mean(self, x, t=None):
        with pyro.plate("data", x.size(0)):
            z = pyro.sample("z", self.z_dist())
            x = pyro.sample("x", self.x_dist(z), obs=x)
            t = pyro.sample("t", self.t_dist(z), obs=t)
        return self.y_dist(t, z).mean

    def z_dist(self):
        return dist.Normal(0, 1).expand([self.latent_dim]).to_event(1)

    def x_dist(self, z):
        loc, scale = self.x_nn(z)
        return dist.Normal(loc, scale).to_event(1)

    def y_dist(self, t, z):
        # Parameters are not shared among t values.
        params0 = self.y0_nn(z)
        params1 = self.y1_nn(z)
        t = t.bool()
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return self.y0_nn.make_dist(*params)

    def t_dist(self, z):
        (logits,) = self.t_nn(z)
        return dist.Bernoulli(logits=logits)


class Guide(PyroModule):
    
    def __init__(self, config):
        self.latent_dim = config["latent_dim"]
        OutcomeNet = DistributionNet.get_class(config["outcome_dist"])
        super().__init__()
        self.t_nn = BernoulliNet([config["feature_dim"]])
        # The y and z networks both follow an architecture where the first few
        # layers are shared for t in {0,1}, but the final layer is split
        # between the two t values.
        self.y_nn = FullyConnected(
            [config["feature_dim"]]
            + [config["hidden_dim"]] * (config["num_layers"] - 1),
            final_activation=nn.ELU(),
        )
        self.y0_nn = OutcomeNet([config["hidden_dim"]])
        self.y1_nn = OutcomeNet([config["hidden_dim"]])
        self.z_nn = FullyConnected(
            [1 + config["feature_dim"]]
            + [config["hidden_dim"]] * (config["num_layers"] - 1),
            final_activation=nn.ELU(),
        )
        self.z0_nn = DiagNormalNet([config["hidden_dim"], config["latent_dim"]])
        self.z1_nn = DiagNormalNet([config["hidden_dim"], config["latent_dim"]])
    def Sample_buffer(self,*args, **kwargs):
      if __builtins__.temp.__class__==list:
        pass

      else:
        __builtins__.temp=[]  

      if kwargs['signal']==True:
        __builtins__.temp=[]

      elif len(__builtins__.temp)<100:
        __builtins__.temp.append(kwargs['data'])

      if  len(__builtins__.temp)==100:
        __builtins__.signal=True  
        __builtins__.temp=[] 
      return __builtins__.temp 

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            # The t and y sites are needed for prediction, and participate in
            # the auxiliary CEVAE loss. We mark them auxiliary to indicate they
            # do not correspond to latent variables during training.
            t = pyro.sample("t", self.t_dist(x), obs=t, infer={"is_auxiliary": True})
            y = pyro.sample("y", self.y_dist(t, x), obs=y, infer={"is_auxiliary": True})
            # The z site participates only in the usual ELBO loss.
            pyro.sample("z", self.z_dist(y, t, x))
            __builtins__.Trans_M_sample=pyro.sample("z_f", self.z_dist(y, t, x))
            # print(type(__builtins__.Trans_M_sample))
            self.Sample_buffer(data=__builtins__.Trans_M_sample, signal=None)
            logger.info('Sample: {}'.format(__builtins__.temp ))

    def forward(self, x, t=None, y=None, size=None):
        if size is None:
            size = x.size(0)
        with pyro.plate("data", size, subsample=x):
            t = pyro.sample("t", self.t_dist(x), obs=t, infer={"is_auxiliary": True})
            y = pyro.sample("y", self.y_dist(t, x), obs=y, infer={"is_auxiliary": True})
            pyro.sample("z", self.z_dist(y, t, x))

    def t_dist(self, x):
        (logits,) = self.t_nn(x)
        return dist.Bernoulli(logits=logits)

    def y_dist(self, t, x):
        hidden = self.y_nn(x)
        params0 = self.y0_nn(hidden)
        params1 = self.y1_nn(hidden)
        t = t.bool()
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return self.y0_nn.make_dist(*params)

    def z_dist(self, y, t, x):
        y_x = torch.cat([y.unsqueeze(-1), x], dim=-1)
        hidden = self.z_nn(y_x)
        params0 = self.z0_nn(hidden)
        params1 = self.z1_nn(hidden)
        t = t.bool().unsqueeze(-1)
        params = [torch.where(t, p1, p0) for p0, p1 in zip(params0, params1)]
        return dist.Normal(*params).to_event(1)


class TraceCausalEffect_ELBO(Trace_ELBO):
    def _differentiable_loss_particle(self, model_trace, guide_trace):
        # Construct -ELBO part.
        blocked_names = [
            name
            for name, site in guide_trace.nodes.items()
            if site["type"] == "sample" and site["is_observed"]
        ]
        blocked_guide_trace = guide_trace.copy()
        for name in blocked_names:
            del blocked_guide_trace.nodes[name]
        loss, surrogate_loss = super()._differentiable_loss_particle(
            model_trace, blocked_guide_trace
        )

        for name in blocked_names:
            log_q = guide_trace.nodes[name]["log_prob_sum"]
            loss = loss - torch_item(log_q)
            surrogate_loss = surrogate_loss - log_q

        return loss, surrogate_loss

    @torch.no_grad()
    def loss(self, model, guide, *args, **kwargs):
        return torch_item(self.differentiable_loss(model, guide, *args, **kwargs))


class CEVAEModel(nn.Module):

    def __init__(
        self,
        feature_dim,
        outcome_dist="bernoulli",
        latent_dim=20,
        hidden_dim=200,
        num_layers=3,
        num_samples=100,
    ):
        config = dict(
            feature_dim=feature_dim,
            latent_dim=latent_dim,
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            num_samples=num_samples,
        )
        for name, size in config.items():
            if not (isinstance(size, int) and size > 0):
                raise ValueError("Expected {} > 0 but got {}".format(name, size))
        config["outcome_dist"] = outcome_dist
        self.feature_dim = feature_dim
        self.num_samples = num_samples

        super().__init__()
        self.model = Model(config)
        self.guide = Guide(config)

    def fit(
        self,
        x,
        t,
        y,
        num_epochs=100,
        batch_size=100,
        learning_rate=1e-3,
        learning_rate_decay=0.1,
        weight_decay=1e-4,
        log_every=100,
    ):

        assert x.dim() == 2 and x.size(-1) == self.feature_dim
        assert t.shape == x.shape[:1]
        assert y.shape == y.shape[:1]
        self.whiten = PreWhitener(x)

        dataset = TensorDataset(x, t, y)
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
        logger.info("Training with {} minibatches per epoch".format(len(dataloader)))
        num_steps = num_epochs * len(dataloader)
        optim = ClippedAdam(
            {
                "lr": learning_rate,
                "weight_decay": weight_decay,
                "lrd": learning_rate_decay ** (1 / num_steps),
            }
        )
        svi = SVI(self.model, self.guide, optim, TraceCausalEffect_ELBO())
        losses = []
        for epoch in range(num_epochs):
            for x, t, y in dataloader:
                x = self.whiten(x)
                loss = svi.step(x, t, y, size=len(dataset)) / len(dataset)
                if log_every and len(losses) % log_every == 0:
                    logger.debug(
                        "step {: >5d} loss = {:0.6g}".format(len(losses), loss)
                    )
                assert not torch_isnan(loss)
                losses.append(loss)
        return losses

    @torch.no_grad()
    def ite(self, x, num_samples=None, batch_size=None):
        
        if num_samples is None:
            num_samples = self.num_samples
        if not torch._C._get_tracing_state():
            assert x.dim() == 2 and x.size(-1) == self.feature_dim

        dataloader = [x] if batch_size is None else DataLoader(x, batch_size=batch_size)
        # logger.info("Evaluating {} minibatches".format(len(dataloader)))
        result = []
        for x in dataloader:
            x = self.whiten(x)
            with pyro.plate("num_particles", num_samples, dim=-2):
                with poutine.trace() as tr, poutine.block(hide=["y", "t"]):
                    self.guide(x)
                with poutine.do(data=dict(t=torch.zeros(()))):
                    y0 = poutine.replay(self.model.y_mean, tr.trace)(x)
                with poutine.do(data=dict(t=torch.ones(()))):
                    y1 = poutine.replay(self.model.y_mean, tr.trace)(x)
            ite = (y1 - y0).mean(0)
            if not torch._C._get_tracing_state():
              pass
              # logger.debug("batch ate = {:0.6g}".format(ite.mean()))
            result.append(ite)
        return torch.cat(result)

    def to_script_module(self):
       
        self.train(False)
        fake_x = torch.randn(2, self.feature_dim)
        with pyro.validation_enabled(False):
            result = torch.jit.trace_module(self, {"ite": (fake_x,)}, check_trace=False)
        return result

#_________________________________________________________________________________

pyro_logger = logging.getLogger("pyro")
pyro_logger.setLevel(logging.DEBUG)
if pyro_logger.handlers:
    pyro_logger.handlers[0].setLevel(logging.DEBUG)


class CEVAE:
    def __init__(self, outcome_dist,latent_dim,hidden_dim,num_epochs,num_layers,
                 batch_size,learning_rate, learning_rate_decay,num_samples=100,weight_decay=1e-4):
    
        self.outcome_dist = __builtins__.outcome_dist
        self.latent_dim = __builtins__.latent_dim
        self.hidden_dim = __builtins__.hidden_dim
        self.num_epochs = __builtins__.num_epochs
        self.num_layers = __builtins__.num_layers
        self.batch_size = __builtins__.batch_size
        self.learning_rate = __builtins__.learning_rate
        self.learning_rate_decay = __builtins__.learning_rate_decay
        self.num_samples = num_samples
        self.weight_decay = weight_decay

    def fit(self, X,treatment,y, p=None):
        
        X, treatment, y = convert_pd_to_np(X, treatment, y)

        self.cevae = CEVAEModel(outcome_dist=self.outcome_dist,
                           feature_dim=X.shape[-1],
                           latent_dim=self.latent_dim,
                           hidden_dim=self.hidden_dim,
                           num_layers=self.num_layers)
        


        self.cevae.fit(x=torch.tensor(X, dtype=torch.float),
                       t=torch.tensor(treatment, dtype=torch.float),
                       y=torch.tensor(y, dtype=torch.float),
                       num_epochs=self.num_epochs,
                       batch_size=self.batch_size,
                       learning_rate=self.learning_rate,
                       learning_rate_decay=self.learning_rate_decay,
                       weight_decay=self.weight_decay)

    def weight_getter(self):
        return Cevae.parameters()

    def predict(self, X, treatment=None, y=None, p=None):
     
        return Cevae.ite(torch.tensor(X, dtype=torch.float),
                              num_samples=self.num_samples,
                              batch_size=self.batch_size)

    def fit_predict(self, X, treatment, y, p=None):
        
        self.fit(X, treatment, y)
        return self.predict(X)

########################################################################################## 
X_train = __builtins__.X_train
treatment_train = __builtins__.treatment_train
y_train = __builtins__.y_train 
########################################################################################## 

# def ite(*args, **kwargs):
  
warnings.filterwarnings('ignore')
logger = logging.getLogger('causalml')
logger.setLevel(logging.DEBUG)
plt.style.use('fivethirtyeight')
sns.set_palette('Paired')
plt.rcParams['figure.figsize'] = (12,8)


cevae = CEVAE(outcome_dist=__builtins__.outcome_dist,
              latent_dim=__builtins__.latent_dim,
              hidden_dim=__builtins__.hidden_dim,
              num_epochs=__builtins__.num_epochs,
              batch_size=__builtins__.batch_size,
              learning_rate=__builtins__.learning_rate,
              learning_rate_decay=__builtins__.learning_rate_decay,
              num_layers=__builtins__.num_layers)



# fit
losses = cevae.fit(X=torch.tensor(X_train, dtype=torch.float),
                  treatment=torch.tensor(treatment_train, dtype=torch.float),
                  y=torch.tensor(y_train, dtype=torch.float))

cevae.predict(X=torch.tensor(X_train, dtype=torch.float))
# Out:
# INFO 	 Training with 6 minibatches per epoc
# DEBUG 	 step  0 loss = 30.947592031954617
# DEBUG 	 step  1 loss = 30.044983654971475
# DEBUG 	 step  2 loss = 29.42065843480981
# DEBUG 	 step  3 loss = 29.527506780422005
# DEBUG 	 step  4 loss = 28.498627894815183
# DEBUG 	 step  5 loss = 28.95808098065179
# DEBUG 	 step  6 loss = 28.166445180936773
# DEBUG 	 step  7 loss = 27.779406896581893
# DEBUG 	 step  8 loss = 26.962428045440365
# DEBUG 	 step  9 loss = 26.9293775975235
# DEBUG 	 step  10 loss = 26.01186564322689
# DEBUG 	 step  11 loss = 25.928431125981415
# DEBUG 	 step  12 loss = 25.53785798219692
# DEBUG 	 step  13 loss = 25.42728398817942
# DEBUG 	 step  14 loss = 24.73490847141558

# %%
#68, 72,75,81,95
cevae.weight_getter()
# Out:
#            0_freqc   1_freqc   2_freqc  ...  97_freqc  98_freqc  99_freqc
# 0_freqc   0.057100  0.006438  0.041690  ...  0.076032  0.000860  0.068675
# 1_freqc   0.063282  0.091687  0.022963  ...  0.032378  0.038767  0.042083
# 2_freqc   0.016723  0.077111  0.051528  ...  0.024843  0.056372  0.039001
# 3_freqc   0.005316  0.062319  0.071449  ...  0.092603  0.047761  0.021490
# 4_freqc   0.037018  0.092454  0.093040  ...  0.005082  0.046737  0.044275
# ...            ...       ...       ...  ...       ...       ...       ...
# 95_freqc  0.004866  0.004573  0.066512  ...  0.035294  0.063793  0.042262
# 96_freqc  0.098817  0.069779  0.017633  ...  0.028696  0.069113  0.092889
# 97_freqc  0.012624  0.019573  0.087357  ...  0.096782  0.016391  0.007332
# 98_freqc  0.009476  0.092629  0.040616  ...  0.090980  0.096109  0.072297
# 99_freqc  0.040613  0.012031  0.012886  ...  0.038859  0.084919  0.079500
#
# [100 rows x 100 columns]
